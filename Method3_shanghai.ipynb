# %%
# !pip install numpy pandas scikit-learn gensim
# Out:
# Requirement already satisfied: numpy in c:\users\owner\python\python311\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\owner\python\python311\lib\site-packages (2.2.3)
# Requirement already satisfied: scikit-learn in c:\users\owner\python\python311\lib\site-packages (1.5.2)
# Requirement already satisfied: gensim in c:\users\owner\python\python311\lib\site-packages (4.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\owner\python\python311\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\owner\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\owner\python\python311\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\owner\python\python311\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\owner\python\python311\lib\site-packages (from scikit-learn) (1.2.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\owner\python\python311\lib\site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: smart-open>=1.8.1 in c:\users\owner\python\python311\lib\site-packages (from gensim) (7.0.5)
# Requirement already satisfied: six>=1.5 in c:\users\owner\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: wrapt in c:\users\owner\python\python311\lib\site-packages (from smart-open>=1.8.1->gensim) (1.17.0)

# %%
import pandas as pd

# 读取文本文件
with open(r'C:\Users\owner\Desktop\KG\OneNYC_2050_Strategic_Plan_final.txt', 'r', encoding='utf-8') as file:
    documents = file.readlines()

# 简单预处理（移除空行）
documents = [doc.strip() for doc in documents if doc.strip()]

# %%
from gensim import corpora
from gensim.models import LdaModel, Phrases
from nltk.tokenize import word_tokenize
import nltk
import matplotlib.pyplot as plt
import networkx as nx
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords

nltk.download('punkt')
nltk.download('stopwords')

# 处理文本中的 "new york city"
def remove_new_york_city(text):
    # 替换 "new york city" 为 "newyorkcity"（避免拆分），然后进行分词
    text = text.replace("new york city", "newyorkcity")
    words = text.split()
    return [word for word in words if word.lower() not in stop_words or word.lower() == "newyorkcity"]

# 定义并更新停用词列表
stop_words = set(stopwords.words('english'))
stop_words.update(["new", "new york","city","students","us","we","since","chief","black","white","bill", "students", "families", "nyc", "york", "public", "community", "communities", "health", "yorker", "yorkers", "state", "onenyc", "2050", "mayor"',"residents',"neighborhood", "also","access","achieve","get","college","children","people","department", "office", "neighborhoods", "school", "schools", "jobs", "care", "increase", "must", "support","end","one","two","three","and","in","on","at","dot","data","high","low","percent","use","mta","fleet","first","second","third","funding","volume","food"])
stop_words = list(stop_words)

# 处理文档数据：去除空行并分词
documents = [doc.strip() for doc in documents if doc.strip()]
tokenized_docs = [word_tokenize(doc.lower()) for doc in documents]
tokenized_docs = [[word for word in doc if word.isalpha() and word not in stop_words] for doc in tokenized_docs]

# 设置种子主题
seed_topics = [
    ['adaptive capacity', 'adaptive','adaptation','adapt', 'adjustment ability', 'adaptation capacity', 'flexibility', 'resilience', 'adaptation', 'coping ability', 'adaptive response', 'climate resilience', 'adaptive management', 'adaptation strategies', 'capacity to adapt', 'system adaptability'],
    ['climate proofing', 'climate proofing', 'climate resilience', 'climate adaptation', 'climate change adaptation', 'climate resilience strategies', 'climate protection', 'climate-smart infrastructure', 'resilient infrastructure', 'climate adaptation measures', 'climate change mitigation'],
    ['vulnerability assessment', 'vulnerability','vulnerable', 'vulnerability analysis', 'risk assessment', 'impact assessment', 'climate risk evaluation', 'climate vulnerability', 'threat analysis', 'hazard assessment', 'vulnerability mapping', 'climate risk analysis', 'resilience assessment'],
    ['ecosystem-based adaptation', 'ecosystem adaptative', 'ecosystem resilience', 'ecosystem change', 'ecosystem', 'ecological adaptation', 'ecosystem response', 'ecological resilience', 'ecosystem transformation', 'environmental adaptation', 'ecosystem sustainability', 'ecosystem-based adaptation', 'ecosystem management'],
    ['resilience', 'resilience', 'resilient', 'adaptive capacity', 'toughness', 'durability', 'robustness', 'resiliency', 'recovery ability', 'strength', 'sustainability', 'robust system', 'climate resilience', 'disaster resilience', 'resilient systems', 'adaptive resilience', 'resilience building'],
    ['transportation planning', 'transportation planning', 'public transport', 'transportation', 'transport', 'public transit', 'transport infrastructure', 'transportation systems', 'urban transport'],
    ['zoning', 'land use regulation', 'urban zoning', 'zoning laws', 'land use planning', 'urban land use', 'land zoning', 'zoning ordinances', 'zoning policies', 'land use regulations', 'zoning codes', 'land use management', 'urban zoning policies', 'spatial zoning'],
    ['urban design', 'design', 'urban development', 'urban form', 'urban planning', 'built environment', 'renewal', 'city layout', 'urban architecture', 'urban planning design', 'sustainable urban design', 'urban space design', 'landscape'],
    ['sustainable development', 'sustainable development', 'sustainability', 'green development', 'sustainable growth', 'eco-friendly development', 'environmental sustainability', 'eco-development', 'green growth', 'environmentally sustainable development', 'sustainable urban development', 'low-carbon development', 'social sustainability', 'economic sustainability', 'sustainability initiatives'],
    ['land use planning', 'land use', 'urban land', 'land development', 'land management', 'land allocation', 'urban land use', 'spatial planning', 'land use policies', 'land planning', 'territorial planning', 'land use zoning', 'land use strategy', 'urban land management', 'land use regulations', 'land use planning policies']
]


# 创建词典和语料
dictionary = corpora.Dictionary(tokenized_docs)
corpus = [dictionary.doc2bow(doc) for doc in tokenized_docs]

# 创建 LDA 模型
lda_model = LdaModel(corpus=corpus, id2word=dictionary, num_topics=len(seed_topics), passes=40, iterations=400, alpha=0.1, random_state=42)

# 提取每个主题的前 top_n_words 个关键词
top_n_words = 10
topic_labels = []

# 获取每个主题的关键词
for i in range(len(lda_model.state.get_lambda())):
    top_words_idx = lda_model.get_topic_terms(i, topn=top_n_words)
    top_words = [dictionary[word_id] for word_id, _ in top_words_idx]
    topic_labels.append(f"Topic {i}: " + ", ".join(top_words))

# 打印主题标签
for label in topic_labels:
    print(label)

# 计算主题之间的相似度（余弦相似度）
topic_word_distributions = lda_model.get_topics()
topic_similarity = cosine_similarity(topic_word_distributions)

# 构建图
G = nx.Graph()
for i in range(len(topic_similarity)):
    for j in range(i + 1, len(topic_similarity)):
        G.add_edge(f"Topic {i}", f"Topic {j}", weight=topic_similarity[i, j])

# 绘制网络图
plt.figure(figsize=(10, 8))
pos = nx.spring_layout(G, k=0.5)  # 定义布局
node_sizes = [len(topic.split(":")[1].split(", ")) * 500 for topic in topic_labels]

nx.draw(
    G, pos, with_labels=True, labels=dict(zip(G.nodes, topic_labels)),
    node_color="skyblue", font_weight="bold", edge_color="gray",
    node_size=node_sizes, font_size=12
)

# 添加边的权重
edge_labels = {(u, v): f"{d['weight']:.2f}" for u, v, d in G.edges(data=True)}
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_size=10)

plt.title("Topic Relationship Graph")
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Topic 0: economic, businesses, residents, workers, poverty, sdgs, work, economy, many, opportunities
# Topic 1: housing, residents, affordable, services, development, program, units, source, plan, million
# Topic 2: infrastructure, projects, bus, emissions, capital, project, carbon, waste, delivery, service
# Topic 3: fair, strong, building, infrastructure, healthy, climate, needs, mental, equity, safe
# Topic 4: parks, social, e, tag, media, early, free, diversity, work, park
# Topic 5: education, programs, program, services, every, training, library, computer, opportunities, tech
# Topic 6: report, bus, economic, solar, global, government, plan, electricity, energy, mayor
# Topic 7: safety, streets, vision, zero, program, pedestrian, traffic, lanes, reduce, enforcement
# Topic 8: mayor, vehicles, reduce, freight, network, transit, transportation, infrastructure, deputy, system
# Topic 9: climate, funded, change, energy, emissions, resiliency, indicators, buildings, continue, action

# %%
# 构建图，将主题和关键词分离，并添加权重
G1 = nx.Graph()

# 模拟权重，或者用实际模型计算的权重替代
# 可以尝试使用更复杂的权重计算方法，以下为示例：
for i, label in enumerate(topic_labels):
    topic_node = f"Topic {i}"  # 中心节点
    G1.add_node(topic_node, type="topic")  # 标记为主题节点
    for word in label.split(": ")[1].split(", "):  # 获取关键词
        G1.add_node(word, type="word")  # 添加关键词节点
        # 假设基于共现次数等其他指标计算权重
        # 这里仍然使用 topic_similarity[i, i] 来模拟计算，实际应替换成更准确的权重计算方式
        weight = topic_similarity[i, i] / (len(label.split(": ")[1].split(", ")) + 1e-5)  # 避免除零错误
        G1.add_edge(topic_node, word, weight=weight)  # 连接到主题节点

# 获取所有边的权重并进行缩放，以便在图中可见
edges = G1.edges(data=True)
weights = [d['weight'] for _, _, d in edges]

# 对权重进行缩放处理，确保边的宽度在绘图时可见
max_weight = max(weights)
scaled_weights = [w / max_weight for w in weights]  # 归一化到 [0, 1] 区间

# 绘制网络图
plt.figure(figsize=(12, 10))
pos = nx.spring_layout(G1, k=0.3)  # 定义布局参数

# 分离主题节点和关键词节点，设置不同的样式
topic_nodes = [node for node, attr in G1.nodes(data=True) if attr['type'] == 'topic']
word_nodes = [node for node, attr in G1.nodes(data=True) if attr['type'] == 'word']

# 绘制主题节点
nx.draw_networkx_nodes(G1, pos, nodelist=topic_nodes, node_color="skyblue", node_size=1500, label="Topics")
nx.draw_networkx_labels(G1, pos, labels={node: node for node in topic_nodes}, font_size=12, font_weight="bold")

# 绘制关键词节点
nx.draw_networkx_nodes(G1, pos, nodelist=word_nodes, node_color="lightgreen", node_size=800, label="Keywords")
nx.draw_networkx_labels(G1, pos, labels={node: node for node in word_nodes}, font_size=10)

# 绘制边，并根据权重调整宽度和颜色
nx.draw_networkx_edges(
    G1, pos, edgelist=edges, edge_color=scaled_weights, edge_cmap=plt.cm.Blues, width=[w * 5 for w in scaled_weights]
)

# 添加边的权重标签
edge_labels = {(u, v): f"{d['weight']:.2f}" for u, v, d in edges}
nx.draw_networkx_edge_labels(G1, pos, edge_labels=edge_labels, font_size=8)

plt.title("Topic and Keywords Network Graph with Edge Weights")
plt.legend(scatterpoints=1, loc="upper left")
plt.show()
# Out:
# C:\Users\owner\AppData\Local\Temp\ipykernel_31624\2904640320.py:41: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   nx.draw_networkx_edges(

# %%
topic_labels
# Out:
# ['Topic 0: economic, businesses, residents, workers, poverty, sdgs, work, economy, many, opportunities',
#  'Topic 1: housing, residents, affordable, services, development, program, units, source, plan, million',
#  'Topic 2: infrastructure, projects, bus, emissions, capital, project, carbon, waste, delivery, service',
#  'Topic 3: fair, strong, building, infrastructure, healthy, climate, needs, mental, equity, safe',
#  'Topic 4: parks, social, e, tag, media, early, free, diversity, work, park',
#  'Topic 5: education, programs, program, services, every, training, library, computer, opportunities, tech',
#  'Topic 6: report, bus, economic, solar, global, government, plan, electricity, energy, mayor',
#  'Topic 7: safety, streets, vision, zero, program, pedestrian, traffic, lanes, reduce, enforcement',
#  'Topic 8: mayor, vehicles, reduce, freight, network, transit, transportation, infrastructure, deputy, system',
#  'Topic 9: climate, funded, change, energy, emissions, resiliency, indicators, buildings, continue, action']

# %%
word_nodes
# Out:
# ['economic',
#  'businesses',
#  'residents',
#  'workers',
#  'poverty',
#  'sdgs',
#  'work',
#  'economy',
#  'many',
#  'opportunities',
#  'housing',
#  'affordable',
#  'services',
#  'development',
#  'program',
#  'units',
#  'source',
#  'plan',
#  'million',
#  'infrastructure',
#  'projects',
#  'bus',
#  'emissions',
#  'capital',
#  'project',
#  'carbon',
#  'waste',
#  'delivery',
#  'service',
#  'fair',
#  'strong',
#  'building',
#  'healthy',
#  'climate',
#  'needs',
#  'mental',
#  'equity',
#  'safe',
#  'parks',
#  'social',
#  'e',
#  'tag',
#  'media',
#  'early',
#  'free',
#  'diversity',
#  'park',
#  'education',
#  'programs',
#  'every',
#  'training',
#  'library',
#  'computer',
#  'tech',
#  'report',
#  'solar',
#  'global',
#  'government',
#  'electricity',
#  'energy',
#  'mayor',
#  'safety',
#  'streets',
#  'vision',
#  'zero',
#  'pedestrian',
#  'traffic',
#  'lanes',
#  'reduce',
#  'enforcement',
#  'vehicles',
#  'freight',
#  'network',
#  'transit',
#  'transportation',
#  'deputy',
#  'system',
#  'funded',
#  'change',
#  'resiliency',
#  'indicators',
#  'buildings',
#  'continue',
#  'action']

# %% [markdown]
# 权重计算扩展
# 可以根据以下方法增强权重计算：
#
# TF-IDF：衡量关键词的重要性。
# Jaccard 相似度：计算固定节点关键词集与 LDA 关键词集的相似度。
# 嵌入向量相似度：将关键词映射到词嵌入空间，计算余弦相似度。

# %%
import networkx as nx
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

# 固定节点列表和关键词
fixed_nodes_list = {
    'resilience': ['resilience', 'resilient', 'adaptive capacity', 'toughness', 'durability', 'robustness', 'resiliency', 'recovery ability', 'strength', 'sustainability', 'robust system', 'climate resilience', 'disaster resilience', 'resilient systems', 'adaptive resilience', 'resilience building'],
    'adaptive capacity': ['adaptive','adaptation','adapt', 'adjustment ability', 'adaptation capacity', 'flexibility', 'resilience', 'adaptation', 'coping ability', 'adaptive response', 'climate resilience', 'adaptive management', 'adaptation strategies', 'capacity to adapt', 'system adaptability'],
    'vulnerability assessment': ['vulnerability','vulnerable', 'vulnerability analysis', 'risk assessment', 'impact assessment', 'climate risk evaluation', 'climate vulnerability', 'threat analysis', 'hazard assessment', 'vulnerability mapping', 'climate risk analysis', 'resilience assessment'],
    'climate proofing': ['climate proofing', 'climate resilience', 'climate adaptation', 'climate change adaptation', 'climate resilience strategies', 'climate protection', 'climate-smart infrastructure', 'resilient infrastructure', 'climate adaptation measures', 'climate change mitigation'],
    'ecosystem-based adaptation': ['ecosystem adaptative', 'ecosystem resilience', 'ecosystem change', 'ecosystem', 'ecological adaptation', 'ecosystem response', 'ecological resilience', 'ecosystem transformation', 'environmental adaptation', 'ecosystem sustainability', 'ecosystem-based adaptation', 'ecosystem management'],
    'zoning': ["district", "area management",'urban zoning', 'district policies', 'district regulations', 'zoning codes', 'land use management', 'urban zoning policies', 'spatial zoning'],
    'land use planning': ['land use', 'urban land', 'land development', 'land management', 'land allocation', 'urban land use', 'spatial planning', 'land use policies', 'land planning', 'territorial planning', 'land use zoning', 'land use strategy', 'urban land management', 'land use regulations', 'land use planning policies'],
    'urban design': ['design', 'urban development', 'urban form', 'urban planning', 'built environment', 'renewal', 'city layout', 'urban architecture', 'urban planning design', 'sustainable urban design', 'urban space design', 'landscape'],
    'transportation planning': ['transportation planning', 'public transport', 'transportation', 'transport', 'public transit', 'transport infrastructure', 'transportation systems', 'urban transport'],
    'sustainable development': ['sustainable development', 'sustainability', 'green development', 'sustainable growth', 'eco-friendly development', 'environmental sustainability', 'eco-development', 'green growth', 'environmentally sustainable development', 'sustainable urban development', 'low-carbon development', 'social sustainability', 'economic sustainability', 'sustainability initiatives']
}
"""
# LDA提取的主题标签
lda_topics = [
    'adaptive capacity and resilience in response to climate change and environmental stress',
    'climate proofing and resilient infrastructure to mitigate climate risks',
    'vulnerability assessment and risk mapping for disaster preparedness',
    'ecosystem-based adaptation focusing on ecological resilience and sustainability',
    'building sustainability and adaptive capacity for resilient communities',
    'transportation planning and sustainable transit systems for urban mobility',
    'urban zoning and spatial policies for effective land use management',
    'urban design and development strategies for livable cities',
    'sustainable development and green initiatives for ecological and social balance',
    'land use planning for integrated urban and rural growth'
]
"""
# 分析关键词
#lda_keywords = [word.strip() for topic in lda_topics for word in topic.split(" ")]
lda_keywords = word_nodes
# 固定节点的关键词作为句子
fixed_nodes_sentences = {node: " ".join(keywords) for node, keywords in fixed_nodes_list.items()}

# LDA关键词集合
lda_sentences = [" ".join(lda_keywords)]  # 合并为一个句子以计算与固定节点的相似性

# 使用TF-IDF向量化关键词
vectorizer = TfidfVectorizer()
fixed_vectors = vectorizer.fit_transform(fixed_nodes_sentences.values())  # 固定节点向量
lda_vector = vectorizer.transform(lda_sentences)  # LDA向量

# 计算余弦相似度
cos_similarities = cosine_similarity(fixed_vectors, lda_vector).flatten()

# 相关性结果存储
correlation_scores = {}
threshold = 0 # 设置阈值

for i, fixed_node in enumerate(fixed_nodes_sentences.keys()):
    for lda_keyword in lda_keywords:
        # 如果关键词在TF-IDF词汇表中，则计算权重
        if lda_keyword in vectorizer.get_feature_names_out():
            lda_index = vectorizer.get_feature_names_out().tolist().index(lda_keyword)
            weight = fixed_vectors[i, lda_index] * lda_vector[0, lda_index]
        else:
            weight = 0

        # 只保留大于阈值的相关性
        if weight >= threshold:
            correlation_scores[(fixed_node, lda_keyword)] = weight

# 查看相关性分数（可以根据需求筛选出高于某个阈值的关键词）
sorted_correlation_scores = sorted(correlation_scores.items(), key=lambda x: -x[1])
for (fixed_node, lda_keyword), score in sorted_correlation_scores[:10]:
    print(f"Correlation between '{fixed_node}' and '{lda_keyword}': {score:.4f}")

#########
# 计算每个固定节点的总相关性分数
node_total_scores = {node: sum(weight for (fixed_nodes_list, lda_keyword), weight in correlation_scores.items() if fixed_nodes_list == node)
                     for node in fixed_nodes_list.keys()}
print(node_total_scores)

# 查看结果
for node, total_score in node_total_scores.items():
    print(f"{node}: {total_score:.4f}")

# 找到最小值和最大值
min_value = min(node_total_scores.values())
max_value = max(node_total_scores.values())

# 归一化到 [10, 1000] 范围
normalized_values = {key: 10 + (total_score - min_value) / (max_value - min_value) * (1000- 10) for key, total_score in node_total_scores.items()}

# 输出归一化后的值
for key, normalized_value in normalized_values.items():
    print(f"{key}: {normalized_value:.2f}")
# 按照固定节点的顺序为每个节点设置大小
node_sizes = {node: normalized_values[node] for node in fixed_nodes_list}
print(node_sizes)
print(fixed_nodes_list)
# 在绘制节点时，提取每个节点对应的大小
sizes = [node_sizes[node] for node in normalized_values]
###############
# Out:
# Correlation between 'climate proofing' and 'climate': 0.1680
# Correlation between 'transportation planning' and 'transportation': 0.1655
# Correlation between 'sustainable development' and 'development': 0.1426
# Correlation between 'climate proofing' and 'infrastructure': 0.0617
# Correlation between 'climate proofing' and 'change': 0.0617
# Correlation between 'resilience' and 'building': 0.0599
# Correlation between 'resilience' and 'resiliency': 0.0599
# Correlation between 'transportation planning' and 'transit': 0.0552
# Correlation between 'vulnerability assessment' and 'climate': 0.0530
# Correlation between 'resilience' and 'system': 0.0433
# {'resilience': 0.18913349027502765, 'adaptive capacity': 0.061878210848540484, 'vulnerability assessment': 0.05300290281621264, 'climate proofing': 0.2913486585312601, 'ecosystem-based adaptation': 0.022956897549021745, 'zoning': 0.0, 'land use planning': 0.01293824537904227, 'urban design': 0.025653311442270597, 'transportation planning': 0.2605139194568083, 'sustainable development': 0.2530990530278295}
# resilience: 0.1891
# adaptive capacity: 0.0619
# vulnerability assessment: 0.0530
# climate proofing: 0.2913
# ecosystem-based adaptation: 0.0230
# zoning: 0.0000
# land use planning: 0.0129
# urban design: 0.0257
# transportation planning: 0.2605
# sustainable development: 0.2531
# resilience: 652.67
# adaptive capacity: 220.26
# vulnerability assessment: 190.10
# climate proofing: 1000.00
# ecosystem-based adaptation: 88.01
# zoning: 10.00
# land use planning: 53.96
# urban design: 97.17
# transportation planning: 895.22
# sustainable development: 870.03
# {'resilience': 652.6738201445584, 'adaptive capacity': 220.26157816848945, 'vulnerability assessment': 190.10336499428385, 'climate proofing': 1000.0, 'ecosystem-based adaptation': 88.00732183942084, 'zoning': 10.0, 'land use planning': 53.964036044729305, 'urban design': 97.16971087451552, 'transportation planning': 895.2238467903159, 'sustainable development': 870.0282004410418}
# {'resilience': ['resilience', 'resilient', 'adaptive capacity', 'toughness', 'durability', 'robustness', 'resiliency', 'recovery ability', 'strength', 'sustainability', 'robust system', 'climate resilience', 'disaster resilience', 'resilient systems', 'adaptive resilience', 'resilience building'], 'adaptive capacity': ['adaptive', 'adaptation', 'adapt', 'adjustment ability', 'adaptation capacity', 'flexibility', 'resilience', 'adaptation', 'coping ability', 'adaptive response', 'climate resilience', 'adaptive management', 'adaptation strategies', 'capacity to adapt', 'system adaptability'], 'vulnerability assessment': ['vulnerability', 'vulnerable', 'vulnerability analysis', 'risk assessment', 'impact assessment', 'climate risk evaluation', 'climate vulnerability', 'threat analysis', 'hazard assessment', 'vulnerability mapping', 'climate risk analysis', 'resilience assessment'], 'climate proofing': ['climate proofing', 'climate resilience', 'climate adaptation', 'climate change adaptation', 'climate resilience strategies', 'climate protection', 'climate-smart infrastructure', 'resilient infrastructure', 'climate adaptation measures', 'climate change mitigation'], 'ecosystem-based adaptation': ['ecosystem adaptative', 'ecosystem resilience', 'ecosystem change', 'ecosystem', 'ecological adaptation', 'ecosystem response', 'ecological resilience', 'ecosystem transformation', 'environmental adaptation', 'ecosystem sustainability', 'ecosystem-based adaptation', 'ecosystem management'], 'zoning': ['district', 'area management', 'urban zoning', 'district policies', 'district regulations', 'zoning codes', 'land use management', 'urban zoning policies', 'spatial zoning'], 'land use planning': ['land use', 'urban land', 'land development', 'land management', 'land allocation', 'urban land use', 'spatial planning', 'land use policies', 'land planning', 'territorial planning', 'land use zoning', 'land use strategy', 'urban land management', 'land use regulations', 'land use planning policies'], 'urban design': ['design', 'urban development', 'urban form', 'urban planning', 'built environment', 'renewal', 'city layout', 'urban architecture', 'urban planning design', 'sustainable urban design', 'urban space design', 'landscape'], 'transportation planning': ['transportation planning', 'public transport', 'transportation', 'transport', 'public transit', 'transport infrastructure', 'transportation systems', 'urban transport'], 'sustainable development': ['sustainable development', 'sustainability', 'green development', 'sustainable growth', 'eco-friendly development', 'environmental sustainability', 'eco-development', 'green growth', 'environmentally sustainable development', 'sustainable urban development', 'low-carbon development', 'social sustainability', 'economic sustainability', 'sustainability initiatives']}

# %%
# 构建图
G = nx.Graph()

# 构建节点和边
for (fixed_node, lda_keyword), score in correlation_scores.items():
    G.add_node(fixed_node, type='fixed')  # 蓝色固定节点
    G.add_node(lda_keyword, type='lda_word')  # 绿色关键词节点
    G.add_edge(fixed_node, lda_keyword, weight=score)

#########################
# 定义自定义顺序列表
custom_order = ['resilience','adaptive capacity','vulnerability assessment','climate proofing','ecosystem-based adaptation','zoning','land use planning','urban design','transportation planning','sustainable development']
#########################

radius_inner = 1.5  # 控制内圈的半径
radius_outer = 2.5  # 控制外圈的半径（可以根据需要调整）

# 绘制布局：固定节点在内圈，关键词节点在外圈
# 获取类型为 'fixed' 的节点
fixed_node_list = [node for node, attr in G.nodes(data=True) if attr['type'] == 'fixed']
# 将节点按照 custom_order 中的顺序排列，如果节点不在 custom_order 中，保持原有顺序
fixed_node_list.sort(key=lambda x: custom_order.index(x) if x in custom_order else float('inf'))
lda_node_list = [node for node, attr in G.nodes(data=True) if attr['type'] == 'lda_word']

# 调整 shell_layout，将内圈的半径设置为 1.5，外圈设置为 2.5
# 使用 shell_layout 来布局节点
shell_layout = [fixed_node_list, lda_node_list]  # 内圈：固定节点，外圈：关键词节点
pos = nx.shell_layout(G, nlist=shell_layout)  # 传递两个列表，不需要嵌套

# 调整内圈半径
for node in fixed_node_list:
    pos[node] = (pos[node][0] * radius_inner, pos[node][1] * radius_inner)

#######################
# 设置旋转角度
rotation_angle = 18 * np.pi / 180  # 36度转换为弧度
# 旋转内圈节点
for node in fixed_node_list:
    x, y = pos[node]  # 获取原始坐标
    r = np.sqrt(x**2 + y**2)  # 计算半径
    theta = np.arctan2(y, x)  # 计算原始角度
    theta += rotation_angle  # 增加36度的旋转
    # 将新的极坐标转换为笛卡尔坐标
    pos[node] = (r * np.cos(theta), r * np.sin(theta))
#######################
# 手动设置节点的位置：内圈的节点（fixed_node_list）和外圈的节点（lda_node_list）
pos = {}

# 按照自定义顺序放置固定节点在内圈
for i, node in enumerate(fixed_node_list):
    angle = 2 * np.pi * i / len(fixed_node_list)
    pos[node] = (radius_inner * np.cos(angle), radius_inner * np.sin(angle))

# 将 LDA 关键词节点放置在外圈
for i, node in enumerate(lda_node_list):
    angle = 2 * np.pi * i / len(lda_node_list)
    pos[node] = (radius_outer * np.cos(angle), radius_outer * np.sin(angle))
# 绘制图形
plt.figure(figsize=(12, 12), facecolor="#ffffff")
# 去掉坐标轴
plt.axis('off')  # 关闭坐标轴
# 绘制固定节点（蓝色，中心较大）
nx.draw_networkx_nodes(
    G, pos, nodelist=fixed_nodes_list, node_color="skyblue", node_size=sizes, label="Fixed Nodes"
)
nx.draw_networkx_labels(G, pos, labels={node: node for node in fixed_node_list}, font_size=12)

# 绘制关键词节点（绿色，外围较小）
nx.draw_networkx_nodes(
    G, pos, nodelist=lda_node_list, node_color="lightgrey", node_size=200, label="LDA Keywords"
)
nx.draw_networkx_labels(G, pos, labels={node: node for node in lda_node_list}, font_size=8)

# 绘制边
edges = G.edges(data=True)
weights = [d['weight'] for _, _, d in edges]
nx.draw_networkx_edges(G, pos, edgelist=edges, edge_color=weights, edge_cmap=plt.cm.Greys, width=[w * 50 for w in weights])

# 添加标题
plt.title("Circular Layout: Fixed Nodes and LDA Keywords Correlation", fontsize=14)
plt.legend(scatterpoints=1, loc="upper right",
           labelspacing=2,
           handlelength=3,
           borderaxespad=2,
           handleheight=2,
           borderpad=1.2)
plt.show()
# Out:
# C:\Users\owner\AppData\Local\Temp\ipykernel_31624\492049810.py:77: DeprecationWarning: `alltrue` is deprecated as of NumPy 1.25.0, and will be removed in NumPy 2.0. Please use `all` instead.
#   nx.draw_networkx_edges(G, pos, edgelist=edges, edge_color=weights, edge_cmap=plt.cm.Greys, width=[w * 50 for w in weights])

# %%
correlation_scores
# Out:
# {('resilience', 'economic'): 0.0,
#  ('resilience', 'businesses'): 0,
#  ('resilience', 'residents'): 0,
#  ('resilience', 'workers'): 0,
#  ('resilience', 'poverty'): 0,
#  ('resilience', 'sdgs'): 0,
#  ('resilience', 'work'): 0,
#  ('resilience', 'economy'): 0,
#  ('resilience', 'many'): 0,
#  ('resilience', 'opportunities'): 0,
#  ('resilience', 'housing'): 0,
#  ('resilience', 'affordable'): 0,
#  ('resilience', 'services'): 0,
#  ('resilience', 'development'): 0.0,
#  ('resilience', 'program'): 0,
#  ('resilience', 'units'): 0,
#  ('resilience', 'source'): 0,
#  ('resilience', 'plan'): 0,
#  ('resilience', 'million'): 0,
#  ('resilience', 'infrastructure'): 0.0,
#  ('resilience', 'projects'): 0,
#  ('resilience', 'bus'): 0,
#  ('resilience', 'emissions'): 0,
#  ('resilience', 'capital'): 0,
#  ('resilience', 'project'): 0,
#  ('resilience', 'carbon'): 0.0,
#  ('resilience', 'waste'): 0,
#  ('resilience', 'delivery'): 0,
#  ('resilience', 'service'): 0,
#  ('resilience', 'fair'): 0,
#  ('resilience', 'strong'): 0,
#  ('resilience', 'building'): 0.059854664923740884,
#  ('resilience', 'healthy'): 0,
#  ('resilience', 'climate'): 0.0261698683750248,
#  ('resilience', 'needs'): 0,
#  ('resilience', 'mental'): 0,
#  ('resilience', 'equity'): 0,
#  ('resilience', 'safe'): 0,
#  ('resilience', 'parks'): 0,
#  ('resilience', 'social'): 0.0,
#  ('resilience', 'e'): 0,
#  ('resilience', 'tag'): 0,
#  ('resilience', 'media'): 0,
#  ('resilience', 'early'): 0,
#  ('resilience', 'free'): 0,
#  ('resilience', 'diversity'): 0,
#  ('resilience', 'park'): 0,
#  ('resilience', 'education'): 0,
#  ('resilience', 'programs'): 0,
#  ('resilience', 'every'): 0,
#  ('resilience', 'training'): 0,
#  ('resilience', 'library'): 0,
#  ('resilience', 'computer'): 0,
#  ('resilience', 'tech'): 0,
#  ('resilience', 'report'): 0,
#  ('resilience', 'solar'): 0,
#  ('resilience', 'global'): 0,
#  ('resilience', 'government'): 0,
#  ('resilience', 'electricity'): 0,
#  ('resilience', 'energy'): 0,
#  ('resilience', 'mayor'): 0,
#  ('resilience', 'safety'): 0,
#  ('resilience', 'streets'): 0,
#  ('resilience', 'vision'): 0,
#  ('resilience', 'zero'): 0,
#  ('resilience', 'pedestrian'): 0,
#  ('resilience', 'traffic'): 0,
#  ('resilience', 'lanes'): 0,
#  ('resilience', 'reduce'): 0,
#  ('resilience', 'enforcement'): 0,
#  ('resilience', 'vehicles'): 0,
#  ('resilience', 'freight'): 0,
#  ('resilience', 'network'): 0,
#  ('resilience', 'transit'): 0.0,
#  ('resilience', 'transportation'): 0.0,
#  ('resilience', 'deputy'): 0,
#  ('resilience', 'system'): 0.043254292052521084,
#  ('resilience', 'funded'): 0,
#  ('resilience', 'change'): 0.0,
#  ('resilience', 'resiliency'): 0.059854664923740884,
#  ('resilience', 'indicators'): 0,
#  ('resilience', 'buildings'): 0,
#  ('resilience', 'continue'): 0,
#  ('resilience', 'action'): 0,
#  ('adaptive capacity', 'economic'): 0.0,
#  ('adaptive capacity', 'businesses'): 0,
#  ('adaptive capacity', 'residents'): 0,
#  ('adaptive capacity', 'workers'): 0,
#  ('adaptive capacity', 'poverty'): 0,
#  ('adaptive capacity', 'sdgs'): 0,
#  ('adaptive capacity', 'work'): 0,
#  ('adaptive capacity', 'economy'): 0,
#  ('adaptive capacity', 'many'): 0,
#  ('adaptive capacity', 'opportunities'): 0,
#  ('adaptive capacity', 'housing'): 0,
#  ('adaptive capacity', 'affordable'): 0,
#  ('adaptive capacity', 'services'): 0,
#  ('adaptive capacity', 'development'): 0.0,
#  ('adaptive capacity', 'program'): 0,
#  ('adaptive capacity', 'units'): 0,
#  ('adaptive capacity', 'source'): 0,
#  ('adaptive capacity', 'plan'): 0,
#  ('adaptive capacity', 'million'): 0,
#  ('adaptive capacity', 'infrastructure'): 0.0,
#  ('adaptive capacity', 'projects'): 0,
#  ('adaptive capacity', 'bus'): 0,
#  ('adaptive capacity', 'emissions'): 0,
#  ('adaptive capacity', 'capital'): 0,
#  ('adaptive capacity', 'project'): 0,
#  ('adaptive capacity', 'carbon'): 0.0,
#  ('adaptive capacity', 'waste'): 0,
#  ('adaptive capacity', 'delivery'): 0,
#  ('adaptive capacity', 'service'): 0,
#  ('adaptive capacity', 'fair'): 0,
#  ('adaptive capacity', 'strong'): 0,
#  ('adaptive capacity', 'building'): 0.0,
#  ('adaptive capacity', 'healthy'): 0,
#  ('adaptive capacity', 'climate'): 0.02332537582328209,
#  ('adaptive capacity', 'needs'): 0,
#  ('adaptive capacity', 'mental'): 0,
#  ('adaptive capacity', 'equity'): 0,
#  ('adaptive capacity', 'safe'): 0,
#  ('adaptive capacity', 'parks'): 0,
#  ('adaptive capacity', 'social'): 0.0,
#  ('adaptive capacity', 'e'): 0,
#  ('adaptive capacity', 'tag'): 0,
#  ('adaptive capacity', 'media'): 0,
#  ('adaptive capacity', 'early'): 0,
#  ('adaptive capacity', 'free'): 0,
#  ('adaptive capacity', 'diversity'): 0,
#  ('adaptive capacity', 'park'): 0,
#  ('adaptive capacity', 'education'): 0,
#  ('adaptive capacity', 'programs'): 0,
#  ('adaptive capacity', 'every'): 0,
#  ('adaptive capacity', 'training'): 0,
#  ('adaptive capacity', 'library'): 0,
#  ('adaptive capacity', 'computer'): 0,
#  ('adaptive capacity', 'tech'): 0,
#  ('adaptive capacity', 'report'): 0,
#  ('adaptive capacity', 'solar'): 0,
#  ('adaptive capacity', 'global'): 0,
#  ('adaptive capacity', 'government'): 0,
#  ('adaptive capacity', 'electricity'): 0,
#  ('adaptive capacity', 'energy'): 0,
#  ('adaptive capacity', 'mayor'): 0,
#  ('adaptive capacity', 'safety'): 0,
#  ('adaptive capacity', 'streets'): 0,
#  ('adaptive capacity', 'vision'): 0,
#  ('adaptive capacity', 'zero'): 0,
#  ('adaptive capacity', 'pedestrian'): 0,
#  ('adaptive capacity', 'traffic'): 0,
#  ('adaptive capacity', 'lanes'): 0,
#  ('adaptive capacity', 'reduce'): 0,
#  ('adaptive capacity', 'enforcement'): 0,
#  ('adaptive capacity', 'vehicles'): 0,
#  ('adaptive capacity', 'freight'): 0,
#  ('adaptive capacity', 'network'): 0,
#  ('adaptive capacity', 'transit'): 0.0,
#  ('adaptive capacity', 'transportation'): 0.0,
#  ('adaptive capacity', 'deputy'): 0,
#  ('adaptive capacity', 'system'): 0.03855283502525839,
#  ('adaptive capacity', 'funded'): 0,
#  ('adaptive capacity', 'change'): 0.0,
#  ('adaptive capacity', 'resiliency'): 0.0,
#  ('adaptive capacity', 'indicators'): 0,
#  ('adaptive capacity', 'buildings'): 0,
#  ('adaptive capacity', 'continue'): 0,
#  ('adaptive capacity', 'action'): 0,
#  ('vulnerability assessment', 'economic'): 0.0,
#  ('vulnerability assessment', 'businesses'): 0,
#  ('vulnerability assessment', 'residents'): 0,
#  ('vulnerability assessment', 'workers'): 0,
#  ('vulnerability assessment', 'poverty'): 0,
#  ('vulnerability assessment', 'sdgs'): 0,
#  ('vulnerability assessment', 'work'): 0,
#  ('vulnerability assessment', 'economy'): 0,
#  ('vulnerability assessment', 'many'): 0,
#  ('vulnerability assessment', 'opportunities'): 0,
#  ('vulnerability assessment', 'housing'): 0,
#  ('vulnerability assessment', 'affordable'): 0,
#  ('vulnerability assessment', 'services'): 0,
#  ('vulnerability assessment', 'development'): 0.0,
#  ('vulnerability assessment', 'program'): 0,
#  ('vulnerability assessment', 'units'): 0,
#  ('vulnerability assessment', 'source'): 0,
#  ('vulnerability assessment', 'plan'): 0,
#  ('vulnerability assessment', 'million'): 0,
#  ('vulnerability assessment', 'infrastructure'): 0.0,
#  ('vulnerability assessment', 'projects'): 0,
#  ('vulnerability assessment', 'bus'): 0,
#  ('vulnerability assessment', 'emissions'): 0,
#  ('vulnerability assessment', 'capital'): 0,
#  ('vulnerability assessment', 'project'): 0,
#  ('vulnerability assessment', 'carbon'): 0.0,
#  ('vulnerability assessment', 'waste'): 0,
#  ('vulnerability assessment', 'delivery'): 0,
#  ('vulnerability assessment', 'service'): 0,
#  ('vulnerability assessment', 'fair'): 0,
#  ('vulnerability assessment', 'strong'): 0,
#  ('vulnerability assessment', 'building'): 0.0,
#  ('vulnerability assessment', 'healthy'): 0,
#  ('vulnerability assessment', 'climate'): 0.05300290281621264,
#  ('vulnerability assessment', 'needs'): 0,
#  ('vulnerability assessment', 'mental'): 0,
#  ('vulnerability assessment', 'equity'): 0,
#  ('vulnerability assessment', 'safe'): 0,
#  ('vulnerability assessment', 'parks'): 0,
#  ('vulnerability assessment', 'social'): 0.0,
#  ('vulnerability assessment', 'e'): 0,
#  ('vulnerability assessment', 'tag'): 0,
#  ('vulnerability assessment', 'media'): 0,
#  ('vulnerability assessment', 'early'): 0,
#  ('vulnerability assessment', 'free'): 0,
#  ('vulnerability assessment', 'diversity'): 0,
#  ('vulnerability assessment', 'park'): 0,
#  ('vulnerability assessment', 'education'): 0,
#  ('vulnerability assessment', 'programs'): 0,
#  ('vulnerability assessment', 'every'): 0,
#  ('vulnerability assessment', 'training'): 0,
#  ('vulnerability assessment', 'library'): 0,
#  ('vulnerability assessment', 'computer'): 0,
#  ('vulnerability assessment', 'tech'): 0,
#  ('vulnerability assessment', 'report'): 0,
#  ('vulnerability assessment', 'solar'): 0,
#  ('vulnerability assessment', 'global'): 0,
#  ('vulnerability assessment', 'government'): 0,
#  ('vulnerability assessment', 'electricity'): 0,
#  ('vulnerability assessment', 'energy'): 0,
#  ('vulnerability assessment', 'mayor'): 0,
#  ('vulnerability assessment', 'safety'): 0,
#  ('vulnerability assessment', 'streets'): 0,
#  ('vulnerability assessment', 'vision'): 0,
#  ('vulnerability assessment', 'zero'): 0,
#  ('vulnerability assessment', 'pedestrian'): 0,
#  ('vulnerability assessment', 'traffic'): 0,
#  ('vulnerability assessment', 'lanes'): 0,
#  ('vulnerability assessment', 'reduce'): 0,
#  ('vulnerability assessment', 'enforcement'): 0,
#  ('vulnerability assessment', 'vehicles'): 0,
#  ('vulnerability assessment', 'freight'): 0,
#  ('vulnerability assessment', 'network'): 0,
#  ('vulnerability assessment', 'transit'): 0.0,
#  ('vulnerability assessment', 'transportation'): 0.0,
#  ('vulnerability assessment', 'deputy'): 0,
#  ('vulnerability assessment', 'system'): 0.0,
#  ('vulnerability assessment', 'funded'): 0,
#  ('vulnerability assessment', 'change'): 0.0,
#  ('vulnerability assessment', 'resiliency'): 0.0,
#  ('vulnerability assessment', 'indicators'): 0,
#  ('vulnerability assessment', 'buildings'): 0,
#  ('vulnerability assessment', 'continue'): 0,
#  ('vulnerability assessment', 'action'): 0,
#  ('climate proofing', 'economic'): 0.0,
#  ('climate proofing', 'businesses'): 0,
#  ('climate proofing', 'residents'): 0,
#  ('climate proofing', 'workers'): 0,
#  ('climate proofing', 'poverty'): 0,
#  ('climate proofing', 'sdgs'): 0,
#  ('climate proofing', 'work'): 0,
#  ('climate proofing', 'economy'): 0,
#  ('climate proofing', 'many'): 0,
#  ('climate proofing', 'opportunities'): 0,
#  ('climate proofing', 'housing'): 0,
#  ('climate proofing', 'affordable'): 0,
#  ('climate proofing', 'services'): 0,
#  ('climate proofing', 'development'): 0.0,
#  ('climate proofing', 'program'): 0,
#  ('climate proofing', 'units'): 0,
#  ('climate proofing', 'source'): 0,
#  ('climate proofing', 'plan'): 0,
#  ('climate proofing', 'million'): 0,
#  ('climate proofing', 'infrastructure'): 0.061692345398323814,
#  ('climate proofing', 'projects'): 0,
#  ('climate proofing', 'bus'): 0,
#  ('climate proofing', 'emissions'): 0,
#  ('climate proofing', 'capital'): 0,
#  ('climate proofing', 'project'): 0,
#  ('climate proofing', 'carbon'): 0.0,
#  ('climate proofing', 'waste'): 0,
#  ('climate proofing', 'delivery'): 0,
#  ('climate proofing', 'service'): 0,
#  ('climate proofing', 'fair'): 0,
#  ('climate proofing', 'strong'): 0,
#  ('climate proofing', 'building'): 0.0,
#  ('climate proofing', 'healthy'): 0,
#  ('climate proofing', 'climate'): 0.16796396773461245,
#  ('climate proofing', 'needs'): 0,
#  ('climate proofing', 'mental'): 0,
#  ('climate proofing', 'equity'): 0,
#  ('climate proofing', 'safe'): 0,
#  ('climate proofing', 'parks'): 0,
#  ('climate proofing', 'social'): 0.0,
#  ('climate proofing', 'e'): 0,
#  ('climate proofing', 'tag'): 0,
#  ('climate proofing', 'media'): 0,
#  ('climate proofing', 'early'): 0,
#  ('climate proofing', 'free'): 0,
#  ('climate proofing', 'diversity'): 0,
#  ('climate proofing', 'park'): 0,
#  ('climate proofing', 'education'): 0,
#  ('climate proofing', 'programs'): 0,
#  ('climate proofing', 'every'): 0,
#  ('climate proofing', 'training'): 0,
#  ('climate proofing', 'library'): 0,
#  ('climate proofing', 'computer'): 0,
#  ('climate proofing', 'tech'): 0,
#  ('climate proofing', 'report'): 0,
#  ('climate proofing', 'solar'): 0,
#  ('climate proofing', 'global'): 0,
#  ('climate proofing', 'government'): 0,
#  ('climate proofing', 'electricity'): 0,
#  ('climate proofing', 'energy'): 0,
#  ('climate proofing', 'mayor'): 0,
#  ('climate proofing', 'safety'): 0,
#  ('climate proofing', 'streets'): 0,
#  ('climate proofing', 'vision'): 0,
#  ('climate proofing', 'zero'): 0,
#  ('climate proofing', 'pedestrian'): 0,
#  ('climate proofing', 'traffic'): 0,
#  ('climate proofing', 'lanes'): 0,
#  ('climate proofing', 'reduce'): 0,
#  ('climate proofing', 'enforcement'): 0,
#  ('climate proofing', 'vehicles'): 0,
#  ('climate proofing', 'freight'): 0,
#  ('climate proofing', 'network'): 0,
#  ('climate proofing', 'transit'): 0.0,
#  ('climate proofing', 'transportation'): 0.0,
#  ('climate proofing', 'deputy'): 0,
#  ('climate proofing', 'system'): 0.0,
#  ('climate proofing', 'funded'): 0,
#  ('climate proofing', 'change'): 0.061692345398323814,
#  ('climate proofing', 'resiliency'): 0.0,
#  ('climate proofing', 'indicators'): 0,
#  ('climate proofing', 'buildings'): 0,
#  ('climate proofing', 'continue'): 0,
#  ('climate proofing', 'action'): 0,
#  ('ecosystem-based adaptation', 'economic'): 0.0,
#  ('ecosystem-based adaptation', 'businesses'): 0,
#  ('ecosystem-based adaptation', 'residents'): 0,
#  ('ecosystem-based adaptation', 'workers'): 0,
#  ('ecosystem-based adaptation', 'poverty'): 0,
#  ('ecosystem-based adaptation', 'sdgs'): 0,
#  ('ecosystem-based adaptation', 'work'): 0,
#  ('ecosystem-based adaptation', 'economy'): 0,
#  ('ecosystem-based adaptation', 'many'): 0,
#  ('ecosystem-based adaptation', 'opportunities'): 0,
#  ('ecosystem-based adaptation', 'housing'): 0,
#  ('ecosystem-based adaptation', 'affordable'): 0,
#  ('ecosystem-based adaptation', 'services'): 0,
#  ('ecosystem-based adaptation', 'development'): 0.0,
#  ('ecosystem-based adaptation', 'program'): 0,
#  ('ecosystem-based adaptation', 'units'): 0,
#  ('ecosystem-based adaptation', 'source'): 0,
#  ('ecosystem-based adaptation', 'plan'): 0,
#  ('ecosystem-based adaptation', 'million'): 0,
#  ('ecosystem-based adaptation', 'infrastructure'): 0.0,
#  ('ecosystem-based adaptation', 'projects'): 0,
#  ('ecosystem-based adaptation', 'bus'): 0,
#  ('ecosystem-based adaptation', 'emissions'): 0,
#  ('ecosystem-based adaptation', 'capital'): 0,
#  ('ecosystem-based adaptation', 'project'): 0,
#  ('ecosystem-based adaptation', 'carbon'): 0.0,
#  ('ecosystem-based adaptation', 'waste'): 0,
#  ('ecosystem-based adaptation', 'delivery'): 0,
#  ('ecosystem-based adaptation', 'service'): 0,
#  ('ecosystem-based adaptation', 'fair'): 0,
#  ('ecosystem-based adaptation', 'strong'): 0,
#  ('ecosystem-based adaptation', 'building'): 0.0,
#  ('ecosystem-based adaptation', 'healthy'): 0,
#  ('ecosystem-based adaptation', 'climate'): 0.0,
#  ('ecosystem-based adaptation', 'needs'): 0,
#  ('ecosystem-based adaptation', 'mental'): 0,
#  ('ecosystem-based adaptation', 'equity'): 0,
#  ('ecosystem-based adaptation', 'safe'): 0,
#  ('ecosystem-based adaptation', 'parks'): 0,
#  ('ecosystem-based adaptation', 'social'): 0.0,
#  ('ecosystem-based adaptation', 'e'): 0,
#  ('ecosystem-based adaptation', 'tag'): 0,
#  ('ecosystem-based adaptation', 'media'): 0,
#  ('ecosystem-based adaptation', 'early'): 0,
#  ('ecosystem-based adaptation', 'free'): 0,
#  ('ecosystem-based adaptation', 'diversity'): 0,
#  ('ecosystem-based adaptation', 'park'): 0,
#  ('ecosystem-based adaptation', 'education'): 0,
#  ('ecosystem-based adaptation', 'programs'): 0,
#  ('ecosystem-based adaptation', 'every'): 0,
#  ('ecosystem-based adaptation', 'training'): 0,
#  ('ecosystem-based adaptation', 'library'): 0,
#  ('ecosystem-based adaptation', 'computer'): 0,
#  ('ecosystem-based adaptation', 'tech'): 0,
#  ('ecosystem-based adaptation', 'report'): 0,
#  ('ecosystem-based adaptation', 'solar'): 0,
#  ('ecosystem-based adaptation', 'global'): 0,
#  ('ecosystem-based adaptation', 'government'): 0,
#  ('ecosystem-based adaptation', 'electricity'): 0,
#  ('ecosystem-based adaptation', 'energy'): 0,
#  ('ecosystem-based adaptation', 'mayor'): 0,
#  ('ecosystem-based adaptation', 'safety'): 0,
#  ('ecosystem-based adaptation', 'streets'): 0,
#  ('ecosystem-based adaptation', 'vision'): 0,
#  ('ecosystem-based adaptation', 'zero'): 0,
#  ('ecosystem-based adaptation', 'pedestrian'): 0,
#  ('ecosystem-based adaptation', 'traffic'): 0,
#  ('ecosystem-based adaptation', 'lanes'): 0,
#  ('ecosystem-based adaptation', 'reduce'): 0,
#  ('ecosystem-based adaptation', 'enforcement'): 0,
#  ('ecosystem-based adaptation', 'vehicles'): 0,
#  ('ecosystem-based adaptation', 'freight'): 0,
#  ('ecosystem-based adaptation', 'network'): 0,
#  ('ecosystem-based adaptation', 'transit'): 0.0,
#  ('ecosystem-based adaptation', 'transportation'): 0.0,
#  ('ecosystem-based adaptation', 'deputy'): 0,
#  ('ecosystem-based adaptation', 'system'): 0.0,
#  ('ecosystem-based adaptation', 'funded'): 0,
#  ('ecosystem-based adaptation', 'change'): 0.022956897549021745,
#  ('ecosystem-based adaptation', 'resiliency'): 0.0,
#  ('ecosystem-based adaptation', 'indicators'): 0,
#  ('ecosystem-based adaptation', 'buildings'): 0,
#  ('ecosystem-based adaptation', 'continue'): 0,
#  ('ecosystem-based adaptation', 'action'): 0,
#  ('zoning', 'economic'): 0.0,
#  ('zoning', 'businesses'): 0,
#  ('zoning', 'residents'): 0,
#  ('zoning', 'workers'): 0,
#  ('zoning', 'poverty'): 0,
#  ('zoning', 'sdgs'): 0,
#  ('zoning', 'work'): 0,
#  ('zoning', 'economy'): 0,
#  ('zoning', 'many'): 0,
#  ('zoning', 'opportunities'): 0,
#  ('zoning', 'housing'): 0,
#  ('zoning', 'affordable'): 0,
#  ('zoning', 'services'): 0,
#  ('zoning', 'development'): 0.0,
#  ('zoning', 'program'): 0,
#  ('zoning', 'units'): 0,
#  ('zoning', 'source'): 0,
#  ('zoning', 'plan'): 0,
#  ('zoning', 'million'): 0,
#  ('zoning', 'infrastructure'): 0.0,
#  ('zoning', 'projects'): 0,
#  ('zoning', 'bus'): 0,
#  ('zoning', 'emissions'): 0,
#  ('zoning', 'capital'): 0,
#  ('zoning', 'project'): 0,
#  ('zoning', 'carbon'): 0.0,
#  ('zoning', 'waste'): 0,
#  ('zoning', 'delivery'): 0,
#  ('zoning', 'service'): 0,
#  ('zoning', 'fair'): 0,
#  ('zoning', 'strong'): 0,
#  ('zoning', 'building'): 0.0,
#  ('zoning', 'healthy'): 0,
#  ('zoning', 'climate'): 0.0,
#  ('zoning', 'needs'): 0,
#  ('zoning', 'mental'): 0,
#  ('zoning', 'equity'): 0,
#  ('zoning', 'safe'): 0,
#  ('zoning', 'parks'): 0,
#  ('zoning', 'social'): 0.0,
#  ('zoning', 'e'): 0,
#  ('zoning', 'tag'): 0,
#  ('zoning', 'media'): 0,
#  ('zoning', 'early'): 0,
#  ('zoning', 'free'): 0,
#  ('zoning', 'diversity'): 0,
#  ('zoning', 'park'): 0,
#  ('zoning', 'education'): 0,
#  ('zoning', 'programs'): 0,
#  ('zoning', 'every'): 0,
#  ('zoning', 'training'): 0,
#  ('zoning', 'library'): 0,
#  ('zoning', 'computer'): 0,
#  ('zoning', 'tech'): 0,
#  ('zoning', 'report'): 0,
#  ('zoning', 'solar'): 0,
#  ('zoning', 'global'): 0,
#  ('zoning', 'government'): 0,
#  ('zoning', 'electricity'): 0,
#  ('zoning', 'energy'): 0,
#  ('zoning', 'mayor'): 0,
#  ('zoning', 'safety'): 0,
#  ('zoning', 'streets'): 0,
#  ('zoning', 'vision'): 0,
#  ('zoning', 'zero'): 0,
#  ('zoning', 'pedestrian'): 0,
#  ('zoning', 'traffic'): 0,
#  ('zoning', 'lanes'): 0,
#  ('zoning', 'reduce'): 0,
#  ('zoning', 'enforcement'): 0,
#  ('zoning', 'vehicles'): 0,
#  ('zoning', 'freight'): 0,
#  ('zoning', 'network'): 0,
#  ('zoning', 'transit'): 0.0,
#  ('zoning', 'transportation'): 0.0,
#  ('zoning', 'deputy'): 0,
#  ('zoning', 'system'): 0.0,
#  ('zoning', 'funded'): 0,
#  ('zoning', 'change'): 0.0,
#  ('zoning', 'resiliency'): 0.0,
#  ('zoning', 'indicators'): 0,
#  ('zoning', 'buildings'): 0,
#  ('zoning', 'continue'): 0,
#  ('zoning', 'action'): 0,
#  ('land use planning', 'economic'): 0.0,
#  ('land use planning', 'businesses'): 0,
#  ('land use planning', 'residents'): 0,
#  ('land use planning', 'workers'): 0,
#  ('land use planning', 'poverty'): 0,
#  ('land use planning', 'sdgs'): 0,
#  ('land use planning', 'work'): 0,
#  ('land use planning', 'economy'): 0,
#  ('land use planning', 'many'): 0,
#  ('land use planning', 'opportunities'): 0,
#  ('land use planning', 'housing'): 0,
#  ('land use planning', 'affordable'): 0,
#  ('land use planning', 'services'): 0,
#  ('land use planning', 'development'): 0.01293824537904227,
#  ('land use planning', 'program'): 0,
#  ('land use planning', 'units'): 0,
#  ('land use planning', 'source'): 0,
#  ('land use planning', 'plan'): 0,
#  ('land use planning', 'million'): 0,
#  ('land use planning', 'infrastructure'): 0.0,
#  ('land use planning', 'projects'): 0,
#  ('land use planning', 'bus'): 0,
#  ('land use planning', 'emissions'): 0,
#  ('land use planning', 'capital'): 0,
#  ('land use planning', 'project'): 0,
#  ('land use planning', 'carbon'): 0.0,
#  ('land use planning', 'waste'): 0,
#  ('land use planning', 'delivery'): 0,
#  ('land use planning', 'service'): 0,
#  ('land use planning', 'fair'): 0,
#  ('land use planning', 'strong'): 0,
#  ('land use planning', 'building'): 0.0,
#  ('land use planning', 'healthy'): 0,
#  ('land use planning', 'climate'): 0.0,
#  ('land use planning', 'needs'): 0,
#  ('land use planning', 'mental'): 0,
#  ('land use planning', 'equity'): 0,
#  ('land use planning', 'safe'): 0,
#  ('land use planning', 'parks'): 0,
#  ('land use planning', 'social'): 0.0,
#  ('land use planning', 'e'): 0,
#  ('land use planning', 'tag'): 0,
#  ('land use planning', 'media'): 0,
#  ('land use planning', 'early'): 0,
#  ('land use planning', 'free'): 0,
#  ('land use planning', 'diversity'): 0,
#  ('land use planning', 'park'): 0,
#  ('land use planning', 'education'): 0,
#  ('land use planning', 'programs'): 0,
#  ('land use planning', 'every'): 0,
#  ('land use planning', 'training'): 0,
#  ('land use planning', 'library'): 0,
#  ('land use planning', 'computer'): 0,
#  ('land use planning', 'tech'): 0,
#  ('land use planning', 'report'): 0,
#  ('land use planning', 'solar'): 0,
#  ('land use planning', 'global'): 0,
#  ('land use planning', 'government'): 0,
#  ('land use planning', 'electricity'): 0,
#  ('land use planning', 'energy'): 0,
#  ('land use planning', 'mayor'): 0,
#  ('land use planning', 'safety'): 0,
#  ('land use planning', 'streets'): 0,
#  ('land use planning', 'vision'): 0,
#  ('land use planning', 'zero'): 0,
#  ('land use planning', 'pedestrian'): 0,
#  ('land use planning', 'traffic'): 0,
#  ('land use planning', 'lanes'): 0,
#  ('land use planning', 'reduce'): 0,
#  ('land use planning', 'enforcement'): 0,
#  ('land use planning', 'vehicles'): 0,
#  ('land use planning', 'freight'): 0,
#  ('land use planning', 'network'): 0,
#  ('land use planning', 'transit'): 0.0,
#  ('land use planning', 'transportation'): 0.0,
#  ('land use planning', 'deputy'): 0,
#  ('land use planning', 'system'): 0.0,
#  ('land use planning', 'funded'): 0,
#  ('land use planning', 'change'): 0.0,
#  ('land use planning', 'resiliency'): 0.0,
#  ('land use planning', 'indicators'): 0,
#  ('land use planning', 'buildings'): 0,
#  ('land use planning', 'continue'): 0,
#  ('land use planning', 'action'): 0,
#  ('urban design', 'economic'): 0.0,
#  ('urban design', 'businesses'): 0,
#  ('urban design', 'residents'): 0,
#  ('urban design', 'workers'): 0,
#  ('urban design', 'poverty'): 0,
#  ('urban design', 'sdgs'): 0,
#  ('urban design', 'work'): 0,
#  ('urban design', 'economy'): 0,
#  ('urban design', 'many'): 0,
#  ('urban design', 'opportunities'): 0,
#  ('urban design', 'housing'): 0,
#  ('urban design', 'affordable'): 0,
#  ('urban design', 'services'): 0,
#  ('urban design', 'development'): 0.025653311442270597,
#  ('urban design', 'program'): 0,
#  ('urban design', 'units'): 0,
#  ('urban design', 'source'): 0,
#  ('urban design', 'plan'): 0,
#  ('urban design', 'million'): 0,
#  ('urban design', 'infrastructure'): 0.0,
#  ('urban design', 'projects'): 0,
#  ('urban design', 'bus'): 0,
#  ('urban design', 'emissions'): 0,
#  ('urban design', 'capital'): 0,
#  ('urban design', 'project'): 0,
#  ('urban design', 'carbon'): 0.0,
#  ('urban design', 'waste'): 0,
#  ('urban design', 'delivery'): 0,
#  ('urban design', 'service'): 0,
#  ('urban design', 'fair'): 0,
#  ('urban design', 'strong'): 0,
#  ('urban design', 'building'): 0.0,
#  ('urban design', 'healthy'): 0,
#  ('urban design', 'climate'): 0.0,
#  ('urban design', 'needs'): 0,
#  ('urban design', 'mental'): 0,
#  ('urban design', 'equity'): 0,
#  ('urban design', 'safe'): 0,
#  ('urban design', 'parks'): 0,
#  ('urban design', 'social'): 0.0,
#  ('urban design', 'e'): 0,
#  ('urban design', 'tag'): 0,
#  ('urban design', 'media'): 0,
#  ('urban design', 'early'): 0,
#  ('urban design', 'free'): 0,
#  ('urban design', 'diversity'): 0,
#  ('urban design', 'park'): 0,
#  ('urban design', 'education'): 0,
#  ('urban design', 'programs'): 0,
#  ('urban design', 'every'): 0,
#  ('urban design', 'training'): 0,
#  ('urban design', 'library'): 0,
#  ('urban design', 'computer'): 0,
#  ('urban design', 'tech'): 0,
#  ('urban design', 'report'): 0,
#  ('urban design', 'solar'): 0,
#  ('urban design', 'global'): 0,
#  ('urban design', 'government'): 0,
#  ('urban design', 'electricity'): 0,
#  ('urban design', 'energy'): 0,
#  ('urban design', 'mayor'): 0,
#  ('urban design', 'safety'): 0,
#  ('urban design', 'streets'): 0,
#  ('urban design', 'vision'): 0,
#  ('urban design', 'zero'): 0,
#  ('urban design', 'pedestrian'): 0,
#  ('urban design', 'traffic'): 0,
#  ('urban design', 'lanes'): 0,
#  ('urban design', 'reduce'): 0,
#  ('urban design', 'enforcement'): 0,
#  ('urban design', 'vehicles'): 0,
#  ('urban design', 'freight'): 0,
#  ('urban design', 'network'): 0,
#  ('urban design', 'transit'): 0.0,
#  ('urban design', 'transportation'): 0.0,
#  ('urban design', 'deputy'): 0,
#  ('urban design', 'system'): 0.0,
#  ('urban design', 'funded'): 0,
#  ('urban design', 'change'): 0.0,
#  ('urban design', 'resiliency'): 0.0,
#  ('urban design', 'indicators'): 0,
#  ('urban design', 'buildings'): 0,
#  ('urban design', 'continue'): 0,
#  ('urban design', 'action'): 0,
#  ('transportation planning', 'economic'): 0.0,
#  ('transportation planning', 'businesses'): 0,
#  ('transportation planning', 'residents'): 0,
#  ('transportation planning', 'workers'): 0,
#  ('transportation planning', 'poverty'): 0,
#  ('transportation planning', 'sdgs'): 0,
#  ('transportation planning', 'work'): 0,
#  ('transportation planning', 'economy'): 0,
#  ('transportation planning', 'many'): 0,
#  ('transportation planning', 'opportunities'): 0,
#  ('transportation planning', 'housing'): 0,
#  ('transportation planning', 'affordable'): 0,
#  ('transportation planning', 'services'): 0,
#  ('transportation planning', 'development'): 0.0,
#  ('transportation planning', 'program'): 0,
#  ('transportation planning', 'units'): 0,
#  ('transportation planning', 'source'): 0,
#  ('transportation planning', 'plan'): 0,
#  ('transportation planning', 'million'): 0,
#  ('transportation planning', 'infrastructure'): 0.03986354225358604,
#  ('transportation planning', 'projects'): 0,
#  ('transportation planning', 'bus'): 0,
#  ('transportation planning', 'emissions'): 0,
#  ('transportation planning', 'capital'): 0,
#  ('transportation planning', 'project'): 0,
#  ('transportation planning', 'carbon'): 0.0,
#  ('transportation planning', 'waste'): 0,
#  ('transportation planning', 'delivery'): 0,
#  ('transportation planning', 'service'): 0,
#  ('transportation planning', 'fair'): 0,
#  ('transportation planning', 'strong'): 0,
#  ('transportation planning', 'building'): 0.0,
#  ('transportation planning', 'healthy'): 0,
#  ('transportation planning', 'climate'): 0.0,
#  ('transportation planning', 'needs'): 0,
#  ('transportation planning', 'mental'): 0,
#  ('transportation planning', 'equity'): 0,
#  ('transportation planning', 'safe'): 0,
#  ('transportation planning', 'parks'): 0,
#  ('transportation planning', 'social'): 0.0,
#  ('transportation planning', 'e'): 0,
#  ('transportation planning', 'tag'): 0,
#  ('transportation planning', 'media'): 0,
#  ('transportation planning', 'early'): 0,
#  ('transportation planning', 'free'): 0,
#  ('transportation planning', 'diversity'): 0,
#  ('transportation planning', 'park'): 0,
#  ('transportation planning', 'education'): 0,
#  ('transportation planning', 'programs'): 0,
#  ('transportation planning', 'every'): 0,
#  ('transportation planning', 'training'): 0,
#  ('transportation planning', 'library'): 0,
#  ('transportation planning', 'computer'): 0,
#  ('transportation planning', 'tech'): 0,
#  ('transportation planning', 'report'): 0,
#  ('transportation planning', 'solar'): 0,
#  ('transportation planning', 'global'): 0,
#  ('transportation planning', 'government'): 0,
#  ('transportation planning', 'electricity'): 0,
#  ('transportation planning', 'energy'): 0,
#  ('transportation planning', 'mayor'): 0,
#  ('transportation planning', 'safety'): 0,
#  ('transportation planning', 'streets'): 0,
#  ('transportation planning', 'vision'): 0,
#  ('transportation planning', 'zero'): 0,
#  ('transportation planning', 'pedestrian'): 0,
#  ('transportation planning', 'traffic'): 0,
#  ('transportation planning', 'lanes'): 0,
#  ('transportation planning', 'reduce'): 0,
#  ('transportation planning', 'enforcement'): 0,
#  ('transportation planning', 'vehicles'): 0,
#  ('transportation planning', 'freight'): 0,
#  ('transportation planning', 'network'): 0,
#  ('transportation planning', 'transit'): 0.05516259430080556,
#  ('transportation planning', 'transportation'): 0.1654877829024167,
#  ('transportation planning', 'deputy'): 0,
#  ('transportation planning', 'system'): 0.0,
#  ('transportation planning', 'funded'): 0,
#  ('transportation planning', 'change'): 0.0,
#  ('transportation planning', 'resiliency'): 0.0,
#  ('transportation planning', 'indicators'): 0,
#  ('transportation planning', 'buildings'): 0,
#  ('transportation planning', 'continue'): 0,
#  ('transportation planning', 'action'): 0,
#  ('sustainable development', 'economic'): 0.03683082836407575,
#  ('sustainable development', 'businesses'): 0,
#  ('sustainable development', 'residents'): 0,
#  ('sustainable development', 'workers'): 0,
#  ('sustainable development', 'poverty'): 0,
#  ('sustainable development', 'sdgs'): 0,
#  ('sustainable development', 'work'): 0,
#  ('sustainable development', 'economy'): 0,
#  ('sustainable development', 'many'): 0,
#  ('sustainable development', 'opportunities'): 0,
#  ('sustainable development', 'housing'): 0,
#  ('sustainable development', 'affordable'): 0,
#  ('sustainable development', 'services'): 0,
#  ('sustainable development', 'development'): 0.14260656793560222,
#  ('sustainable development', 'program'): 0,
#  ('sustainable development', 'units'): 0,
#  ('sustainable development', 'source'): 0,
#  ('sustainable development', 'plan'): 0,
#  ('sustainable development', 'million'): 0,
#  ('sustainable development', 'infrastructure'): 0.0,
#  ('sustainable development', 'projects'): 0,
#  ('sustainable development', 'bus'): 0,
#  ('sustainable development', 'emissions'): 0,
#  ('sustainable development', 'capital'): 0,
#  ('sustainable development', 'project'): 0,
#  ('sustainable development', 'carbon'): 0.03683082836407575,
#  ('sustainable development', 'waste'): 0,
#  ('sustainable development', 'delivery'): 0,
#  ('sustainable development', 'service'): 0,
#  ('sustainable development', 'fair'): 0,
#  ('sustainable development', 'strong'): 0,
#  ('sustainable development', 'building'): 0.0,
#  ('sustainable development', 'healthy'): 0,
#  ('sustainable development', 'climate'): 0.0,
#  ('sustainable development', 'needs'): 0,
#  ('sustainable development', 'mental'): 0,
#  ('sustainable development', 'equity'): 0,
#  ('sustainable development', 'safe'): 0,
#  ('sustainable development', 'parks'): 0,
#  ('sustainable development', 'social'): 0.03683082836407575,
#  ('sustainable development', 'e'): 0,
#  ('sustainable development', 'tag'): 0,
#  ('sustainable development', 'media'): 0,
#  ('sustainable development', 'early'): 0,
#  ('sustainable development', 'free'): 0,
#  ('sustainable development', 'diversity'): 0,
#  ('sustainable development', 'park'): 0,
#  ('sustainable development', 'education'): 0,
#  ('sustainable development', 'programs'): 0,
#  ('sustainable development', 'every'): 0,
#  ('sustainable development', 'training'): 0,
#  ('sustainable development', 'library'): 0,
#  ('sustainable development', 'computer'): 0,
#  ('sustainable development', 'tech'): 0,
#  ('sustainable development', 'report'): 0,
#  ('sustainable development', 'solar'): 0,
#  ('sustainable development', 'global'): 0,
#  ('sustainable development', 'government'): 0,
#  ('sustainable development', 'electricity'): 0,
#  ('sustainable development', 'energy'): 0,
#  ('sustainable development', 'mayor'): 0,
#  ('sustainable development', 'safety'): 0,
#  ('sustainable development', 'streets'): 0,
#  ('sustainable development', 'vision'): 0,
#  ('sustainable development', 'zero'): 0,
#  ('sustainable development', 'pedestrian'): 0,
#  ('sustainable development', 'traffic'): 0,
#  ('sustainable development', 'lanes'): 0,
#  ('sustainable development', 'reduce'): 0,
#  ('sustainable development', 'enforcement'): 0,
#  ('sustainable development', 'vehicles'): 0,
#  ('sustainable development', 'freight'): 0,
#  ('sustainable development', 'network'): 0,
#  ('sustainable development', 'transit'): 0.0,
#  ('sustainable development', 'transportation'): 0.0,
#  ('sustainable development', 'deputy'): 0,
#  ('sustainable development', 'system'): 0.0,
#  ('sustainable development', 'funded'): 0,
#  ('sustainable development', 'change'): 0.0,
#  ('sustainable development', 'resiliency'): 0.0,
#  ('sustainable development', 'indicators'): 0,
#  ('sustainable development', 'buildings'): 0,
#  ('sustainable development', 'continue'): 0,
#  ('sustainable development', 'action'): 0}

# %%
# 查看结果
for node, total_score in node_total_scores.items():
    print(f"{node}: {total_score:.4f}")
# Out:
# resilience: 0.1891
# adaptive capacity: 0.0619
# vulnerability assessment: 0.0530
# climate proofing: 0.2913
# ecosystem-based adaptation: 0.0230
# zoning: 0.0000
# land use planning: 0.0129
# urban design: 0.0257
# transportation planning: 0.2605
# sustainable development: 0.2531

# %%
topic_labels
# Out:
# ['Topic 0: economic, businesses, residents, workers, poverty, sdgs, work, economy, many, opportunities',
#  'Topic 1: housing, residents, affordable, services, development, program, units, source, plan, million',
#  'Topic 2: infrastructure, projects, bus, emissions, capital, project, carbon, waste, delivery, service',
#  'Topic 3: fair, strong, building, infrastructure, healthy, climate, needs, mental, equity, safe',
#  'Topic 4: parks, social, e, tag, media, early, free, diversity, work, park',
#  'Topic 5: education, programs, program, services, every, training, library, computer, opportunities, tech',
#  'Topic 6: report, bus, economic, solar, global, government, plan, electricity, energy, mayor',
#  'Topic 7: safety, streets, vision, zero, program, pedestrian, traffic, lanes, reduce, enforcement',
#  'Topic 8: mayor, vehicles, reduce, freight, network, transit, transportation, infrastructure, deputy, system',
#  'Topic 9: climate, funded, change, energy, emissions, resiliency, indicators, buildings, continue, action']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import networkx as nx
import matplotlib.pyplot as plt

# 定义固定节点和 LDA 主题节点
fixed_nodes = {
    'adaptive capacity': ['adaptive', 'adaptation', 'adapt', 'adjustment ability', 'adaptation capacity', 'flexibility', 'resilience', 'adaptation', 'coping ability', 'adaptive response', 'climate resilience', 'adaptive management', 'adaptation strategies', 'capacity to adapt', 'system adaptability'],
    'climate proofing': ['climate proofing', 'climate resilience', 'climate adaptation', 'climate change adaptation', 'climate resilience strategies', 'climate protection', 'climate-smart infrastructure', 'resilient infrastructure', 'climate adaptation measures', 'climate change mitigation'],
    'vulnerability assessment': ['vulnerability', 'vulnerable', 'vulnerability analysis', 'risk assessment', 'impact assessment', 'climate risk evaluation', 'climate vulnerability', 'threat analysis', 'hazard assessment', 'vulnerability mapping', 'climate risk analysis', 'resilience assessment'],
    'ecosystem-based adaptation': ['ecosystem adaptative', 'ecosystem resilience', 'ecosystem change', 'ecosystem', 'ecological adaptation', 'ecosystem response', 'ecological resilience', 'ecosystem transformation', 'environmental adaptation', 'ecosystem sustainability', 'ecosystem-based adaptation', 'ecosystem management'],
    'resilience': ['resilience', 'resilient', 'adaptive capacity', 'toughness', 'durability', 'robustness', 'resiliency', 'recovery ability', 'strength', 'sustainability', 'robust system', 'climate resilience', 'disaster resilience', 'resilient systems', 'adaptive resilience', 'resilience building'],
    'transportation planning': ['transportation planning', 'public transport', 'transportation', 'transport', 'public transit', 'transport infrastructure', 'transportation systems', 'urban transport'],
    'zoning': ['zoning', 'land use regulation', 'urban zoning', 'zoning laws', 'land use planning', 'urban land use', 'land zoning', 'zoning ordinances', 'zoning policies', 'land use regulations', 'zoning codes', 'land use management', 'urban zoning policies', 'spatial zoning'],
    'urban design': ['urban design', 'city planning', 'urban development', 'city design', 'urban form', 'urban planning', 'built environment', 'urban renewal', 'city layout', 'urban architecture', 'urban planning design', 'sustainable urban design', 'urban space design', 'city landscape design'],
    'sustainable development': ['sustainable development', 'sustainability', 'green development', 'sustainable growth', 'eco-friendly development', 'environmental sustainability', 'eco-development', 'green growth', 'environmentally sustainable development', 'sustainable urban development', 'low-carbon development', 'social sustainability', 'economic sustainability', 'sustainability initiatives'],
    'land use planning': ['land use', 'urban land', 'land development', 'land management', 'land allocation', 'urban land use', 'spatial planning', 'land use policies', 'land planning', 'territorial planning', 'land use zoning', 'land use strategy', 'urban land management', 'land use regulations', 'land use planning policies']
}

# 解析主题标签
lda_topics = [
    'adaptive capacity and resilience in response to climate change and environmental stress',
    'climate proofing and resilient infrastructure to mitigate climate risks',
    'vulnerability assessment and risk mapping for disaster preparedness',
    'ecosystem-based adaptation focusing on ecological resilience and sustainability',
    'building sustainability and adaptive capacity for resilient communities',
    'transportation planning and sustainable transit systems for urban mobility',
    'urban zoning and spatial policies for effective land use management',
    'urban design and development strategies for livable cities',
    'sustainable development and green initiatives for ecological and social balance',
    'land use planning for integrated urban and rural growth'
]


# 合并所有节点文本
all_texts = []

# 将 fixed_nodes 的关键词添加到 all_texts
for node in fixed_nodes.values():
    all_texts.extend(node)

# 将 lda_topics 的标签添加到 all_texts
all_texts.extend(lda_topics)

# 使用 TF-IDF 计算相似性
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(all_texts)
similarity_matrix = cosine_similarity(tfidf_matrix)

# 创建网络图
G = nx.Graph()

# 添加固定节点
for node in fixed_nodes:
    G.add_node(node, type="fixed", color="darkblue", size=800)

# 添加主题节点
for topic in word_nodes:
    G.add_node(topic, type="topic", color="lightblue", size=400)

# 添加边（相似度阈值 > 0.2）
threshold = 0.2
for i, fixed_node in enumerate(fixed_nodes):
    for j, word_node in enumerate(word_nodes, len(fixed_nodes)):
        similarity = similarity_matrix[i, j]
        if similarity > threshold:  # 设置相似度阈值
            G.add_edge(fixed_node, word_node, weight=round(similarity, 2))

# 提取节点颜色和大小
node_colors = [nx.get_node_attributes(G, 'color')[node] for node in G.nodes]
node_sizes = [nx.get_node_attributes(G, 'size')[node] for node in G.nodes]

# 绘制网络图
plt.figure(figsize=(14, 12))
pos = nx.spring_layout(G, k=0.5, seed=42)  # 固定布局以便可重复生成

# 绘制节点
nx.draw_networkx_nodes(G, pos, node_color=node_colors, node_size=node_sizes)

# 绘制标签
nx.draw_networkx_labels(G, pos, font_size=10)

# 绘制边
edges = G.edges(data=True)
weights = [d['weight'] for _, _, d in edges]
nx.draw_networkx_edges(
    G, pos, edgelist=edges, edge_color="gray", alpha=0.7, width=[w * 2 for w in weights]
)

# 添加边的权重标签
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(
    G, pos, edge_labels={k: f"{v}" for k, v in edge_labels.items()},
    font_size=8, label_pos=0.5
)

plt.title("Semantic Similarity Network: Fixed Nodes vs LDA Topics", fontsize=16)
plt.show()

# %%
lda_model.save('lda_model')

# %%
from gensim.models import LdaModel
lda_model = LdaModel.load('lda_model')

# %%
for idx, doc in enumerate(corpus):
    topic_probs = lda_model.get_document_topics(doc, minimum_probability=0.1)
    print(f"Document {idx}: {topic_probs}")
# Out:
# Document 0: [(3, 0.99476665)]
# Document 1: [(8, 0.9639939)]
# Document 2: [(1, 0.94994354)]
# Document 3: [(6, 0.9964692)]
# Document 4: [(0, 0.14265229), (1, 0.31231746), (3, 0.38386127), (8, 0.12031789)]
# Document 5: [(3, 0.27321133), (4, 0.61324257), (9, 0.1103765)]
# Document 6: [(3, 0.5018794), (4, 0.48033047)]
# Document 7: [(1, 0.31485087), (3, 0.6793044)]
# Document 8: [(1, 0.63354325), (3, 0.33442602)]
# Document 9: [(8, 0.6997912)]
# Document 10: [(0, 0.47914433), (4, 0.4241765)]
# Document 11: [(0, 0.24395363), (3, 0.16959676), (5, 0.19749719), (7, 0.16639012), (9, 0.1586101)]
# Document 12: [(0, 0.5206208), (2, 0.24429561), (7, 0.1431201)]
# Document 13: [(5, 0.9571167)]
# Document 14: [(0, 0.7166833), (3, 0.1301441), (9, 0.14843997)]
# Document 15: [(0, 0.9356599)]
# Document 16: [(3, 0.9921711)]
# Document 17: [(3, 0.99560857)]
# Document 18: [(3, 0.959088)]
# Document 19: [(3, 0.9939991)]
# Document 20: [(0, 0.5498832)]
# Document 21: [(0, 0.60086244), (3, 0.12255425), (9, 0.268621)]
# Document 22: [(0, 0.90996706)]
# Document 23: [(1, 0.99505216)]
# Document 24: [(1, 0.9075244)]
# Document 25: [(0, 0.1), (1, 0.1), (2, 0.1), (3, 0.1), (4, 0.1), (5, 0.1), (6, 0.1), (7, 0.1), (8, 0.1), (9, 0.1)]
# Document 26: [(0, 0.34356165), (6, 0.65133977)]
# Document 27: [(1, 0.21152003), (5, 0.78350794)]
# Document 28: [(1, 0.7749582)]
# Document 29: [(1, 0.910121)]
# Document 30: [(1, 0.7407869), (3, 0.1622726)]
# Document 31: [(6, 0.99317837)]
# Document 32: [(0, 0.3867961), (3, 0.58818525)]
# Document 33: [(0, 0.6288266), (3, 0.33116028)]
# Document 34: [(1, 0.9971231)]
# Document 35: [(1, 0.8823906), (3, 0.11212567)]
# Document 36: [(0, 0.29152307), (1, 0.61147565)]
# Document 37: [(0, 0.5216901), (6, 0.4745694)]
# Document 38: [(8, 0.9099645)]
# Document 39: [(6, 0.899957)]
# Document 40: [(0, 0.9193761)]
# Document 41: [(0, 0.1), (1, 0.1), (2, 0.1), (3, 0.1), (4, 0.1), (5, 0.1), (6, 0.1), (7, 0.1), (8, 0.1), (9, 0.1)]
# Document 42: [(0, 0.4109051), (1, 0.3206164), (3, 0.114415035), (7, 0.14626469)]
# Document 43: [(2, 0.43581372), (9, 0.558848)]
# Document 44: [(6, 0.6772814), (9, 0.31683266)]
# Document 45: [(9, 0.94370115)]
# Document 46: [(0, 0.5778099), (2, 0.41973403)]
# Document 47: [(2, 0.549954)]
# Document 48: [(0, 0.43562692), (6, 0.51614726)]
# Document 49: [(0, 0.1), (1, 0.1), (2, 0.1), (3, 0.1), (4, 0.1), (5, 0.1), (6, 0.1), (7, 0.1), (8, 0.1), (9, 0.1)]
# Document 50: [(0, 0.99440575)]
# Document 51: [(0, 0.40771204), (1, 0.5211614)]
# Document 52: [(0, 0.1), (1, 0.1), (2, 0.1), (3, 0.1), (4, 0.1), (5, 0.1), (6, 0.1), (7, 0.1), (8, 0.1), (9, 0.1)]
# Document 53: [(0, 0.15714233), (1, 0.4299344), (3, 0.40753204)]
# Document 54: [(6, 0.96998334)]
# Document 55: [(1, 0.9958304)]
# Document 56: [(1, 0.9915047)]
# Document 57: [(1, 0.15421563), (3, 0.8412346)]
# Document 58: [(3, 0.54991776)]
# Document 59: [(0, 0.18324678), (1, 0.37363797), (3, 0.44046116)]
# Document 60: [(0, 0.5416512), (3, 0.45402235)]
# Document 61: [(3, 0.9166355)]
# Document 62: [(1, 0.3390771), (3, 0.5895972)]
# Document 63: [(0, 0.12116034), (3, 0.33171266), (5, 0.14571396), (9, 0.3980592)]
# Document 64: [(2, 0.2485485), (3, 0.549202), (7, 0.19862013)]
# Document 65: [(1, 0.6640113), (3, 0.32821482)]
# Document 66: [(3, 0.2958701), (6, 0.6967862)]
# Document 67: [(1, 0.59634846), (3, 0.3295325)]
# Document 68: [(4, 0.14797297), (6, 0.51887244), (8, 0.29812682)]
# Document 69: [(0, 0.4530661), (1, 0.25382298), (9, 0.28780198)]
# Document 70: [(0, 0.67785686), (3, 0.31687593)]
# Document 71: [(0, 0.43921322), (3, 0.11428768), (6, 0.3019635), (9, 0.14198066)]
# Document 72: [(0, 0.37601945), (5, 0.4094609), (9, 0.19040933)]
# Document 73: [(0, 0.82852846), (3, 0.16843912)]
# Document 74: [(8, 0.549453)]
# Document 75: [(1, 0.60149175), (6, 0.3336434)]
# Document 76: [(6, 0.9006027)]
# Document 77: [(0, 0.30376524), (1, 0.44806537), (2, 0.12572695), (9, 0.11861726)]
# Document 78: [(8, 0.99806696)]
# Document 79: [(8, 0.9952345)]
# Document 80: [(3, 0.69427), (9, 0.2897187)]
# Document 81: [(3, 0.4224473), (4, 0.49754548)]
# Document 82: [(3, 0.9499965)]
# Document 83: [(3, 0.99467367)]
# Document 84: [(4, 0.84999)]
# Document 85: [(3, 0.99470514)]
# Document 86: [(3, 0.93999517)]
# Document 87: [(0, 0.6271444), (3, 0.31534526)]
# Document 88: [(0, 0.19895947), (9, 0.6675775)]
# Document 89: [(0, 0.9959068)]
# Document 90: [(0, 0.1), (1, 0.1), (2, 0.1), (3, 0.1), (4, 0.1), (5, 0.1), (6, 0.1), (7, 0.1), (8, 0.1), (9, 0.1)]
# Document 91: [(0, 0.5477466), (9, 0.44838583)]
# Document 92: [(0, 0.24505633), (1, 0.24815288), (2, 0.29722598), (3, 0.20249955)]
# Document 93: [(7, 0.6945044), (8, 0.25840494)]
# Document 94: [(0, 0.5966187), (3, 0.26187766), (6, 0.1317737)]
# Document 95: [(1, 0.8713774)]
# Document 96: [(0, 0.6868987), (4, 0.30800232)]
# Document 97: [(0, 0.57353777), (7, 0.41045117)]
# Document 98: [(0, 0.9181583)]
# Document 99: [(4, 0.9749877)]
# Document 100: [(1, 0.9970179)]
# Document 101: [(1, 0.8462924), (4, 0.103671625)]
# Document 102: [(3, 0.35159367), (5, 0.64138174)]
# Document 103: [(5, 0.9921685)]
# Document 104: [(5, 0.22688773), (6, 0.7663284)]
# Document 105: [(0, 0.9927951)]
# Document 106: [(0, 0.73980665), (5, 0.18228106)]
# Document 107: [(0, 0.30165756), (6, 0.6850017)]
# Document 108: [(1, 0.84906465)]
# Document 109: [(0, 0.1), (1, 0.1), (2, 0.1), (3, 0.1), (4, 0.1), (5, 0.1), (6, 0.1), (7, 0.1), (8, 0.1), (9, 0.1)]
# Document 110: [(2, 0.9098929)]
# Document 111: [(0, 0.6198915), (6, 0.37466285)]
# Document 112: [(0, 0.6104331), (8, 0.3844663)]
# Document 113: [(0, 0.41398963), (5, 0.58037204)]
# Document 114: [(0, 0.47553098), (3, 0.29252836), (7, 0.2217861)]
# Document 115: [(3, 0.5703071), (5, 0.41107)]
# Document 116: [(0, 0.33121616), (8, 0.6266445)]
# Document 117: [(0, 0.3807501), (3, 0.14566745), (7, 0.4687843)]
# Document 118: [(1, 0.45200026), (6, 0.4568752)]
# Document 119: [(2, 0.6604224), (5, 0.32388186)]
# Document 120: [(0, 0.9971947)]
# Document 121: [(7, 0.91815)]
# Document 122: [(3, 0.16032527), (9, 0.8354617)]
# Document 123: [(0, 0.291536), (9, 0.7020079)]
# Document 124: [(0, 0.87803966)]
# Document 125: [(0, 0.5227099), (9, 0.4721262)]
# Document 126: [(0, 0.17461854), (9, 0.7309505)]
# Document 127: [(0, 0.23565364), (1, 0.31608343), (3, 0.38356227)]
# Document 128: [(8, 0.9624939)]
# Document 129: [(3, 0.9499959)]
# Document 130: [(3, 0.9941554)]
# Document 131: [(8, 0.9437471)]
# Document 132: [(4, 0.84998995)]
# Document 133: [(3, 0.994736)]
# Document 134: [(3, 0.9399939)]
# Document 135: [(0, 0.99337935)]
# Document 136: [(0, 0.9968844)]
# Document 137: [(0, 0.4828723), (4, 0.5011157)]
# Document 138: [(0, 0.9438766)]
# Document 139: [(0, 0.50629586), (1, 0.29585078), (4, 0.16926557)]
# Document 140: [(0, 0.6013195), (6, 0.3908327)]
# Document 141: [(0, 0.4174887), (3, 0.20851414), (5, 0.3100184)]
# Document 142: [(1, 0.42244366), (5, 0.5740599)]
# Document 143: [(1, 0.48210812), (2, 0.25676674), (9, 0.1832605)]
# Document 144: [(5, 0.79211533), (9, 0.20447885)]
# Document 145: [(1, 0.41857308), (5, 0.19972509), (8, 0.3367895)]
# Document 146: [(0, 0.22006953), (1, 0.7050952)]
# Document 147: [(5, 0.9972633)]
# Document 148: [(7, 0.98927975)]
# Document 149: [(1, 0.98940414)]
# Document 150: [(0, 0.37015224), (5, 0.23025468), (8, 0.3363211)]
# Document 151: [(0, 0.99611807)]
# Document 152: [(1, 0.7384942), (3, 0.25783214)]
# Document 153: [(0, 0.21553813), (1, 0.595632), (8, 0.17131653)]
# Document 154: [(1, 0.56267464), (5, 0.1632313), (9, 0.21364106)]
# Document 155: [(1, 0.5049192), (8, 0.41166472)]
# Document 156: [(0, 0.57151306), (1, 0.42338705)]
# Document 157: [(0, 0.7321717), (5, 0.25781986)]
# Document 158: [(0, 0.84703165), (6, 0.14981602)]
# Document 159: [(1, 0.42162693), (7, 0.5721191)]
# Document 160: [(0, 0.8499027), (4, 0.14493218)]
# Document 161: [(0, 0.99337864)]
# Document 162: [(0, 0.6319597), (1, 0.17402932), (9, 0.19144501)]
# Document 163: [(3, 0.12403799), (6, 0.7427127)]
# Document 164: [(8, 0.9951061)]
# Document 165: [(2, 0.99528515)]
# Document 166: [(0, 0.27856052), (8, 0.71673006)]
# Document 167: [(0, 0.53389484), (9, 0.46158355)]
# Document 168: [(0, 0.56829756), (9, 0.42563814)]
# Document 169: [(3, 0.27521142), (7, 0.524582)]
# Document 170: [(0, 0.767144), (3, 0.11724761), (4, 0.11093798)]
# Document 171: [(8, 0.96249366)]
# Document 172: [(3, 0.9357079)]
# Document 173: [(3, 0.9941554)]
# Document 174: [(8, 0.94374704)]
# Document 175: [(4, 0.849989)]
# Document 176: [(3, 0.9947361)]
# Document 177: [(3, 0.9181712)]
# Document 178: [(0, 0.595572), (1, 0.39858374)]
# Document 179: [(0, 0.3224859), (1, 0.5821279)]
# Document 180: [(1, 0.9931261)]
# Document 181: [(1, 0.4063576), (2, 0.19110788), (7, 0.17791127), (9, 0.14963081)]
# Document 182: [(1, 0.5896704), (8, 0.40807402)]
# Document 183: [(0, 0.5605361), (1, 0.25438088), (3, 0.17396569)]
# Document 184: [(1, 0.7273201), (8, 0.25838006)]
# Document 185: [(1, 0.5618165), (7, 0.43446022)]
# Document 186: [(1, 0.6680828), (8, 0.3282948)]
# Document 187: [(1, 0.9964823)]
# Document 188: [(1, 0.99573255)]
# Document 189: [(1, 0.9965234)]
# Document 190: [(0, 0.1), (1, 0.1), (2, 0.1), (3, 0.1), (4, 0.1), (5, 0.1), (6, 0.1), (7, 0.1), (8, 0.1), (9, 0.1)]
# Document 191: [(1, 0.84399056), (3, 0.15020938)]
# Document 192: [(1, 0.9921024)]
# Document 193: [(1, 0.21181844), (3, 0.45323288), (4, 0.32925355)]
# Document 194: [(5, 0.9896501)]
# Document 195: [(0, 0.28880072), (1, 0.3004208), (2, 0.15851323), (3, 0.23509929)]
# Document 196: [(1, 0.24905899), (3, 0.4719977), (7, 0.2618595)]
# Document 197: [(3, 0.27443907), (5, 0.57566667), (9, 0.14557007)]
# Document 198: [(5, 0.7863051), (7, 0.20696762)]
# Document 199: [(1, 0.9917372)]
# Document 200: [(1, 0.35266355), (8, 0.6344246)]
# Document 201: [(5, 0.97691053)]
# Document 202: [(4, 0.9956501)]
# Document 203: [(0, 0.9958689)]
# Document 204: [(0, 0.9920299)]
# Document 205: [(0, 0.5260987), (6, 0.461393)]
# Document 206: [(0, 0.15323809), (5, 0.81536293)]
# Document 207: [(5, 0.9964266)]
# Document 208: [(1, 0.6695807), (3, 0.3188187)]
# Document 209: [(1, 0.73841906), (9, 0.24823551)]
# Document 210: [(3, 0.16210401), (7, 0.82947016)]
# Document 211: [(1, 0.33538124), (7, 0.56888306)]
# Document 212: [(7, 0.99361354)]
# Document 213: [(5, 0.9154202)]
# Document 214: [(4, 0.9938743)]
# Document 215: [(2, 0.9951835)]
# Document 216: [(2, 0.99603236)]
# Document 217: [(0, 0.1), (1, 0.1), (2, 0.1), (3, 0.1), (4, 0.1), (5, 0.1), (6, 0.1), (7, 0.1), (8, 0.1), (9, 0.1)]
# Document 218: [(1, 0.89680815)]
# Document 219: [(1, 0.8653204), (3, 0.12870619)]
# Document 220: [(1, 0.58751714), (7, 0.40368548)]
# Document 221: [(5, 0.99387413)]
# Document 222: [(1, 0.5002289), (8, 0.48572588)]
# Document 223: [(1, 0.48769706), (9, 0.50778097)]
# Document 224: [(7, 0.15949938), (9, 0.7617538)]
# Document 225: [(3, 0.7715269), (4, 0.2228752)]
# Document 226: [(8, 0.96249413)]
# Document 227: [(3, 0.95908815)]
# Document 228: [(3, 0.9941554)]
# Document 229: [(8, 0.94374704)]
# Document 230: [(4, 0.84998995)]
# Document 231: [(3, 0.9947361)]
# Document 232: [(3, 0.95262796)]
# Document 233: [(0, 0.6978956), (3, 0.29599378)]
# Document 234: [(9, 0.8874826)]
# Document 235: [(0, 0.92813355)]
# Document 236: [(3, 0.25527748), (7, 0.73638386)]
# Document 237: [(1, 0.3812828), (2, 0.46551332), (3, 0.14023036)]
# Document 238: [(0, 0.68738455), (3, 0.30840287)]
# Document 239: [(1, 0.20017058), (2, 0.19511962), (3, 0.4746371), (9, 0.12598693)]
# Document 240: [(0, 0.93568546)]
# Document 241: [(3, 0.91352093)]
# Document 242: [(2, 0.97040534)]
# Document 243: [(2, 0.98523676)]
# Document 244: [(2, 0.98083943)]
# Document 245: [(3, 0.2182322), (7, 0.7334478)]
# Document 246: [(0, 0.5499103)]
# Document 247: [(0, 0.9049617)]
# Document 248: [(1, 0.9812327)]
# Document 249: [(1, 0.5004389), (3, 0.4574361)]
# Document 250: [(1, 0.40745986), (3, 0.5571198)]
# Document 251: [(1, 0.29701087), (3, 0.6965845)]
# Document 252: [(1, 0.6869753), (3, 0.30646127)]
# Document 253: [(0, 0.25946528), (3, 0.40034667), (4, 0.108563125), (8, 0.22479932)]
# Document 254: [(3, 0.4971526), (7, 0.49704415)]
# Document 255: [(0, 0.9906181)]
# Document 256: [(5, 0.9903172)]
# Document 257: [(3, 0.122233875), (5, 0.19359024), (9, 0.6770991)]
# Document 258: [(0, 0.16157115), (2, 0.20062168), (3, 0.46524143), (5, 0.16801618)]
# Document 259: [(3, 0.9939133)]
# Document 260: [(3, 0.42112124), (7, 0.5667499)]
# Document 261: [(3, 0.33797228), (6, 0.56198245)]
# Document 262: [(7, 0.92300314)]
# Document 263: [(1, 0.6776439), (7, 0.23332037)]
# Document 264: [(3, 0.42185813), (7, 0.26661673), (9, 0.30907482)]
# Document 265: [(8, 0.38787708), (9, 0.59701425)]
# Document 266: [(9, 0.995831)]
# Document 267: [(0, 0.14447984), (8, 0.8525976)]
# Document 268: [(3, 0.9971405)]
# Document 269: [(3, 0.7420893), (9, 0.23929101)]
# Document 270: [(4, 0.20172651), (9, 0.79449785)]
# Document 271: [(4, 0.81994146)]
# Document 272: [(9, 0.96346486)]
# Document 273: [(3, 0.47832188), (9, 0.5157475)]
# Document 274: [(3, 0.993473)]
# Document 275: [(8, 0.9624945)]
# Document 276: [(3, 0.9437455)]
# Document 277: [(3, 0.9941554)]
# Document 278: [(8, 0.9571392)]
# Document 279: [(3, 0.9947361)]
# Document 280: [(3, 0.93076247)]
# Document 281: [(0, 0.4209243), (5, 0.40820074), (7, 0.16667931)]
# Document 282: [(0, 0.45195183), (3, 0.38812095), (5, 0.15603422)]
# Document 283: [(5, 0.38474435), (7, 0.60890293)]
# Document 284: [(5, 0.9948546)]
# Document 285: [(0, 0.39250898), (3, 0.12175553), (5, 0.38570887)]
# Document 286: [(5, 0.59703076), (7, 0.3970401)]
# Document 287: [(7, 0.9923048)]
# Document 288: [(4, 0.99780947)]
# Document 289: [(1, 0.35449785), (5, 0.36576846), (9, 0.18505536)]
# Document 290: [(5, 0.93075156)]
# Document 291: [(1, 0.46354), (5, 0.53086156)]
# Document 292: [(0, 0.1), (1, 0.1), (2, 0.1), (3, 0.1), (4, 0.1), (5, 0.1), (6, 0.1), (7, 0.1), (8, 0.1), (9, 0.1)]
# Document 293: [(1, 0.19466731), (5, 0.57820237), (7, 0.21282956)]
# Document 294: [(5, 0.98473704)]
# Document 295: [(5, 0.98888326)]
# Document 296: [(3, 0.304411), (7, 0.68707246)]
# Document 297: [(5, 0.9905232)]
# Document 298: [(5, 0.9967376)]
# Document 299: [(2, 0.55914533), (5, 0.38369352)]
# Document 300: [(5, 0.7585311), (7, 0.18655136)]
# Document 301: [(5, 0.991425)]
# Document 302: [(1, 0.9971594)]
# Document 303: [(4, 0.99556416)]
# Document 304: [(0, 0.98084366)]
# Document 305: [(6, 0.7749091)]
# Document 306: [(5, 0.9937027)]
# Document 307: [(1, 0.9934731)]
# Document 308: [(5, 0.97905356)]
# Document 309: [(7, 0.99444157)]
# Document 310: [(1, 0.9947328)]
# Document 311: [(5, 0.34382862), (9, 0.65080005)]
# Document 312: [(5, 0.25859645), (9, 0.7301304)]
# Document 313: [(3, 0.22780298), (4, 0.15399423), (5, 0.28093606), (6, 0.33242428)]
# Document 314: [(3, 0.51571494), (8, 0.46428218)]
# Document 315: [(3, 0.9941554)]
# Document 316: [(8, 0.94374704)]
# Document 317: [(4, 0.84998995)]
# Document 318: [(3, 0.9947667)]
# Document 319: [(3, 0.9357066)]
# Document 320: [(3, 0.1545037), (6, 0.24267623), (9, 0.52718467)]
# Document 321: [(0, 0.25585818), (8, 0.46005332), (9, 0.28191933)]
# Document 322: [(2, 0.3129343), (3, 0.273356), (9, 0.39526376)]
# Document 323: [(8, 0.42296946), (9, 0.5737896)]
# Document 324: [(6, 0.29515523), (9, 0.69483757)]
# Document 325: [(2, 0.66929024), (9, 0.32674605)]
# Document 326: [(0, 0.1), (1, 0.1), (2, 0.1), (3, 0.1), (4, 0.1), (5, 0.1), (6, 0.1), (7, 0.1), (8, 0.1), (9, 0.1)]
# Document 327: [(3, 0.47309124), (9, 0.52305865)]
# Document 328: [(0, 0.39915806), (3, 0.15131707), (9, 0.44692045)]
# Document 329: [(0, 0.28241444), (3, 0.5365971), (7, 0.16969)]
# Document 330: [(0, 0.24166918), (2, 0.41663295), (9, 0.25730845)]
# Document 331: [(2, 0.7831535), (9, 0.21373205)]
# Document 332: [(6, 0.77170575), (9, 0.22569549)]
# Document 333: [(9, 0.99395615)]
# Document 334: [(6, 0.98695123)]
# Document 335: [(2, 0.6669663), (9, 0.32562086)]
# Document 336: [(2, 0.93997836)]
# Document 337: [(2, 0.24413604), (9, 0.7535964)]
# Document 338: [(8, 0.9961189)]
# Document 339: [(2, 0.3965326), (7, 0.32207134), (8, 0.19616567)]
# Document 340: [(2, 0.9867572)]
# Document 341: [(2, 0.9602286)]
# Document 342: [(2, 0.9960329)]
# Document 343: [(6, 0.98860115)]
# Document 344: [(9, 0.98391736)]
# Document 345: [(0, 0.5278855), (2, 0.44198278)]
# Document 346: [(0, 0.78019893), (3, 0.21100143)]
# Document 347: [(8, 0.8136159), (9, 0.18247926)]
# Document 348: [(2, 0.54988825)]
# Document 349: [(1, 0.5149212), (9, 0.4790137)]
# Document 350: [(2, 0.51665294), (9, 0.4771399)]
# Document 351: [(3, 0.24890333), (9, 0.7475706)]
# Document 352: [(1, 0.34123605), (3, 0.17749645), (9, 0.38901308)]
# Document 353: [(8, 0.98234266)]
# Document 354: [(1, 0.69268936), (9, 0.2989713)]
# Document 355: [(1, 0.75461644), (9, 0.23055667)]
# Document 356: [(9, 0.997038)]
# Document 357: [(9, 0.9942647)]
# Document 358: [(2, 0.23897792), (5, 0.37156513), (9, 0.38472316)]
# Document 359: [(9, 0.99296516)]
# Document 360: [(1, 0.5058354), (8, 0.11276052), (9, 0.37285942)]
# Document 361: [(9, 0.9949698)]
# Document 362: [(2, 0.42016172), (9, 0.57467324)]
# Document 363: [(1, 0.37595615), (9, 0.6077015)]
# Document 364: [(2, 0.5949661), (9, 0.38933662)]
# Document 365: [(1, 0.1680319), (9, 0.82763946)]
# Document 366: [(9, 0.9920341)]
# Document 367: [(3, 0.53300565), (4, 0.11036779), (9, 0.25867435)]
# Document 368: [(8, 0.9624945)]
# Document 369: [(3, 0.9399953)]
# Document 370: [(3, 0.9941554)]
# Document 371: [(8, 0.9437471)]
# Document 372: [(4, 0.84999)]
# Document 373: [(3, 0.9947361)]
# Document 374: [(3, 0.92499304)]
# Document 375: [(0, 0.1612297), (2, 0.8033042)]
# Document 376: [(0, 0.32443538), (2, 0.40318465), (3, 0.19225802)]
# Document 377: [(0, 0.1), (1, 0.1), (2, 0.1), (3, 0.1), (4, 0.1), (5, 0.1), (6, 0.1), (7, 0.1), (8, 0.1), (9, 0.1)]
# Document 378: [(2, 0.9962164)]
# Document 379: [(2, 0.20213085), (3, 0.18743072), (7, 0.35484695), (8, 0.25123766)]
# Document 380: [(2, 0.88046736), (7, 0.11119525)]
# Document 381: [(7, 0.98523957)]
# Document 382: [(2, 0.7238949), (3, 0.2189461)]
# Document 383: [(2, 0.9763055)]
# Document 384: [(2, 0.36724734), (7, 0.10157433), (8, 0.52747226)]
# Document 385: [(2, 0.99090457)]
# Document 386: [(1, 0.36942878), (2, 0.14793234), (3, 0.23486267), (8, 0.20942484)]
# Document 387: [(8, 0.99630916)]
# Document 388: [(6, 0.9023492)]
# Document 389: [(1, 0.14246236), (2, 0.3832052), (7, 0.37145278)]
# Document 390: [(7, 0.6065259), (8, 0.3883101)]
# Document 391: [(7, 0.9962012)]
# Document 392: [(2, 0.36507767), (7, 0.6255033)]
# Document 393: [(1, 0.23859257), (7, 0.47462064), (9, 0.27277106)]
# Document 394: [(5, 0.61252236), (7, 0.37816793)]
# Document 395: [(7, 0.3529585), (9, 0.63852525)]
# Document 396: [(5, 0.21947965), (6, 0.3780365), (7, 0.36746657)]
# Document 397: [(6, 0.99010515)]
# Document 398: [(7, 0.9929105)]
# Document 399: [(7, 0.41472515), (8, 0.5758561)]
# Document 400: [(7, 0.37114644), (8, 0.62309504)]
# Document 401: [(7, 0.992238)]
# Document 402: [(6, 0.4734987), (7, 0.5009119)]
# Document 403: [(2, 0.23709194), (5, 0.34184733), (8, 0.31975263)]
# Document 404: [(3, 0.44926202), (7, 0.4706782)]
# Document 405: [(7, 0.99766135)]
# Document 406: [(2, 0.99285465)]
# Document 407: [(2, 0.27659816), (5, 0.50465524), (8, 0.21096642)]
# Document 408: [(2, 0.99623203)]
# Document 409: [(8, 0.99684066)]
# Document 410: [(8, 0.7749849)]
# Document 411: [(6, 0.5171367), (8, 0.4776654)]
# Document 412: [(6, 0.99482495)]
# Document 413: [(1, 0.46829146), (2, 0.1430594), (8, 0.38616467)]
# Document 414: [(1, 0.44049174), (2, 0.20157789), (8, 0.35346776)]
# Document 415: [(7, 0.9963835)]
# Document 416: [(5, 0.996263)]
# Document 417: [(2, 0.15732644), (7, 0.15647474), (9, 0.6818224)]
# Document 418: [(8, 0.35679534), (9, 0.61741006)]
# Document 419: [(3, 0.13331456), (4, 0.8071993)]
# Document 420: [(3, 0.4863857), (8, 0.49255893)]
# Document 421: [(3, 0.9941554)]
# Document 422: [(8, 0.94374704)]
# Document 423: [(4, 0.84999)]
# Document 424: [(3, 0.9948564)]
# Document 425: [(3, 0.9249925)]
# Document 426: [(0, 0.53851825), (2, 0.45656916)]
# Document 427: [(0, 0.45597893), (2, 0.35771638), (3, 0.18356723)]
# Document 428: [(0, 0.81995964)]
# Document 429: [(2, 0.9958117)]
# Document 430: [(2, 0.99540555)]
# Document 431: [(2, 0.29568973), (3, 0.11989461), (6, 0.56598514)]
# Document 432: [(7, 0.3792714), (9, 0.540639)]
# Document 433: [(2, 0.27264243), (3, 0.17734542), (5, 0.5035329)]
# Document 434: [(2, 0.58059627), (4, 0.4135604)]
# Document 435: [(3, 0.9836207)]
# Document 436: [(2, 0.64280075), (5, 0.34180406)]
# Document 437: [(1, 0.19483809), (8, 0.7948994)]
# Document 438: [(4, 0.77496517)]
# Document 439: [(8, 0.98162293)]
# Document 440: [(2, 0.4468683), (5, 0.55039907)]
# Document 441: [(8, 0.9981472)]
# Document 442: [(1, 0.99606675)]
# Document 443: [(0, 0.5111664), (2, 0.48417893)]
# Document 444: [(2, 0.99523544)]
# Document 445: [(2, 0.6656946), (5, 0.24349959)]
# Document 446: [(0, 0.42949668), (2, 0.12828124), (4, 0.43542176)]
# Document 447: [(0, 0.761619), (2, 0.23407587)]
# Document 448: [(5, 0.9954291)]
# Document 449: [(2, 0.9833239)]
# Document 450: [(1, 0.90072304)]
# Document 451: [(2, 0.9937464)]
# Document 452: [(2, 0.3259344), (4, 0.6694919)]
# Document 453: [(1, 0.49498114), (2, 0.49998304)]
# Document 454: [(1, 0.563822), (2, 0.4321133)]
# Document 455: [(2, 0.99644077)]
# Document 456: [(2, 0.9963247)]
# Document 457: [(2, 0.66828), (7, 0.29702812)]
# Document 458: [(3, 0.9399458)]
# Document 459: [(0, 0.1123126), (2, 0.18487452), (9, 0.697206)]
# Document 460: [(1, 0.24082413), (2, 0.45544508), (9, 0.2989324)]
# Document 461: [(4, 0.99577266)]
# Document 462: [(8, 0.9624945)]

# %%
import numpy as np

# 假设 corpus 是一个文档列表，lda_model 是训练好的 LDA 模型
total_documents = len(corpus)
topic_frequencies = np.zeros(lda_model.num_topics)

# 遍历每个文档
for doc in corpus:
    # 获取该文档在每个主题上的概率分布
    topic_probs = lda_model.get_document_topics(doc, minimum_probability=0.1)

    # 累加每个主题的概率值
    for topic_id, prob in topic_probs:
        topic_frequencies[topic_id] += prob

# 计算每个主题的平均概率，即出现频率
topic_frequencies /= total_documents

# 输出各个主题的频率
for topic_id, frequency in enumerate(topic_frequencies):
    print(f"Topic {topic_id}: Frequency = {frequency:.4f}")
# Out:
# Topic 0: Frequency = 0.1352
# Topic 1: Frequency = 0.1341
# Topic 2: Frequency = 0.1024
# Topic 3: Frequency = 0.1591
# Topic 4: Frequency = 0.0465
# Topic 5: Frequency = 0.0839
# Topic 6: Frequency = 0.0518
# Topic 7: Frequency = 0.0682
# Topic 8: Frequency = 0.0907
# Topic 9: Frequency = 0.0918

# %%
# 获取主题-词分布
topic_word_distributions = lda_model.get_topics()

# 获取文档-主题分布
document_topic_distributions = [
    lda_model.get_document_topics(doc, minimum_probability=0.0) for doc in corpus
]
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# 转换为矩阵形式
doc_topic_matrix = np.array([
    [topic_prob[1] for topic_prob in sorted(doc, key=lambda x: x[0])]
    for doc in document_topic_distributions
])
print(doc_topic_matrix)
# 绘制热力图
plt.figure(figsize=(12, 6))
sns.heatmap(doc_topic_matrix, cmap="YlGnBu", cbar_kws={'label': 'Topic Probability'})
plt.xlabel("Topics")
plt.ylabel("Documents")
plt.title("Document-Topic Distribution Heatmap")
plt.show()
# Out:
# [[5.8147695e-04 5.8147009e-04 5.8146147e-04 ... 5.8145274e-04
#   5.8164529e-04 5.8147707e-04]
#  [4.0007103e-03 4.0005213e-03 4.0005208e-03 ... 4.0005459e-03
#   9.6399415e-01 4.0004924e-03]
#  [5.5621583e-03 9.4994324e-01 5.5614803e-03 ... 5.5622826e-03
#   5.5631390e-03 5.5627627e-03]
#  ...
#  [6.8548607e-04 2.4082239e-01 4.5544648e-01 ... 6.8542827e-04
#   6.8541808e-04 2.9893270e-01]
#  [4.6969854e-04 4.6971336e-04 4.6970334e-04 ... 4.6965963e-04
#   4.6966679e-04 4.6967142e-04]
#  [4.1671232e-03 4.1670408e-03 4.1669030e-03 ... 4.1669062e-03
#   9.6249419e-01 4.1669868e-03]]

# %%
import numpy as np

# 假设doc_topic_matrix是文档-主题分布矩阵
# doc_topic_matrix.shape = (num_docs, num_topics)

# 设置一个阈值，表示哪些主题的权重视为“存在”该主题
threshold = 0.1  # 可根据需要调整阈值

# 计算主题共现矩阵
num_topics = doc_topic_matrix.shape[1]
cooccurrence_matrix = np.zeros((num_topics, num_topics))

# 遍历每个文档
for doc in doc_topic_matrix:
    # 获取权重大于阈值的主题索引
    active_topics = np.where(doc > threshold)[0]

    # 计算这些主题的共现
    for i in range(len(active_topics)):
        for j in range(i + 1, len(active_topics)):
            cooccurrence_matrix[active_topics[i], active_topics[j]] += 1
            cooccurrence_matrix[active_topics[j], active_topics[i]] += 1

# 可视化共现矩阵
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.heatmap(cooccurrence_matrix, annot=True, cmap="YlGnBu", xticklabels=range(num_topics), yticklabels=range(num_topics))
plt.title("Topic Co-occurrence Matrix")
plt.xlabel("Topic")
plt.ylabel("Topic")
plt.show()

# 如果需要归一化共现频率，可以除以文档总数
cooccurrence_matrix_normalized = cooccurrence_matrix / doc_topic_matrix.shape[0]

# 可视化归一化后的共现矩阵
plt.figure(figsize=(10, 8))
sns.heatmap(cooccurrence_matrix_normalized, annot=True, cmap="YlGnBu", xticklabels=range(num_topics), yticklabels=range(num_topics))
plt.title("Normalized Topic Co-occurrence Matrix")
plt.xlabel("Topic")
plt.ylabel("Topic")
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# 假设共现矩阵是通过某种方式计算出来的，这里我们直接用一个示例矩阵
# 你需要将实际的共现权重填充到这个矩阵
word_cooccurrence_matrix = np.random.rand(len(word_nodes), len(word_nodes))  # 示例随机生成的矩阵

# 确保矩阵是对称的
word_cooccurrence_matrix = (word_cooccurrence_matrix + word_cooccurrence_matrix.T) / 2

# 输出词与词的共现矩阵
print("Word-Word Co-occurrence Matrix:")
print(word_cooccurrence_matrix)

# 可视化词与词的共现矩阵（热力图）
plt.figure(figsize=(12, 8))
sns.heatmap(word_cooccurrence_matrix, cmap="YlGnBu", xticklabels=word_nodes, yticklabels=word_nodes, annot=False)
plt.title("Word-Word Co-occurrence Matrix")
plt.xlabel("Word Nodes")
plt.ylabel("Word Nodes")
plt.show()
# Out:
# Word-Word Co-occurrence Matrix:
# [[0.03331247 0.65411791 0.10212929 ... 0.4703789  0.71779766 0.32970543]
#  [0.65411791 0.00442618 0.49452368 ... 0.48603565 0.51492343 0.19049379]
#  [0.10212929 0.49452368 0.6731955  ... 0.33965398 0.37858489 0.67445367]
#  ...
#  [0.4703789  0.48603565 0.33965398 ... 0.09058214 0.34918108 0.1444423 ]
#  [0.71779766 0.51492343 0.37858489 ... 0.34918108 0.59920861 0.55590744]
#  [0.32970543 0.19049379 0.67445367 ... 0.1444423  0.55590744 0.05017679]]

# %%
correlation_scores
# Out:
# {('resilience', 'economic'): 0.0,
#  ('resilience', 'businesses'): 0,
#  ('resilience', 'residents'): 0,
#  ('resilience', 'workers'): 0,
#  ('resilience', 'poverty'): 0,
#  ('resilience', 'sdgs'): 0,
#  ('resilience', 'work'): 0,
#  ('resilience', 'economy'): 0,
#  ('resilience', 'many'): 0,
#  ('resilience', 'opportunities'): 0,
#  ('resilience', 'housing'): 0,
#  ('resilience', 'affordable'): 0,
#  ('resilience', 'services'): 0,
#  ('resilience', 'development'): 0.0,
#  ('resilience', 'program'): 0,
#  ('resilience', 'units'): 0,
#  ('resilience', 'source'): 0,
#  ('resilience', 'plan'): 0,
#  ('resilience', 'million'): 0,
#  ('resilience', 'infrastructure'): 0.0,
#  ('resilience', 'projects'): 0,
#  ('resilience', 'bus'): 0,
#  ('resilience', 'emissions'): 0,
#  ('resilience', 'capital'): 0,
#  ('resilience', 'project'): 0,
#  ('resilience', 'carbon'): 0.0,
#  ('resilience', 'waste'): 0,
#  ('resilience', 'delivery'): 0,
#  ('resilience', 'service'): 0,
#  ('resilience', 'fair'): 0,
#  ('resilience', 'strong'): 0,
#  ('resilience', 'building'): 0.059854664923740884,
#  ('resilience', 'healthy'): 0,
#  ('resilience', 'climate'): 0.0261698683750248,
#  ('resilience', 'needs'): 0,
#  ('resilience', 'mental'): 0,
#  ('resilience', 'equity'): 0,
#  ('resilience', 'safe'): 0,
#  ('resilience', 'parks'): 0,
#  ('resilience', 'social'): 0.0,
#  ('resilience', 'e'): 0,
#  ('resilience', 'tag'): 0,
#  ('resilience', 'media'): 0,
#  ('resilience', 'early'): 0,
#  ('resilience', 'free'): 0,
#  ('resilience', 'diversity'): 0,
#  ('resilience', 'park'): 0,
#  ('resilience', 'education'): 0,
#  ('resilience', 'programs'): 0,
#  ('resilience', 'every'): 0,
#  ('resilience', 'training'): 0,
#  ('resilience', 'library'): 0,
#  ('resilience', 'computer'): 0,
#  ('resilience', 'tech'): 0,
#  ('resilience', 'report'): 0,
#  ('resilience', 'solar'): 0,
#  ('resilience', 'global'): 0,
#  ('resilience', 'government'): 0,
#  ('resilience', 'electricity'): 0,
#  ('resilience', 'energy'): 0,
#  ('resilience', 'mayor'): 0,
#  ('resilience', 'safety'): 0,
#  ('resilience', 'streets'): 0,
#  ('resilience', 'vision'): 0,
#  ('resilience', 'zero'): 0,
#  ('resilience', 'pedestrian'): 0,
#  ('resilience', 'traffic'): 0,
#  ('resilience', 'lanes'): 0,
#  ('resilience', 'reduce'): 0,
#  ('resilience', 'enforcement'): 0,
#  ('resilience', 'vehicles'): 0,
#  ('resilience', 'freight'): 0,
#  ('resilience', 'network'): 0,
#  ('resilience', 'transit'): 0.0,
#  ('resilience', 'transportation'): 0.0,
#  ('resilience', 'deputy'): 0,
#  ('resilience', 'system'): 0.043254292052521084,
#  ('resilience', 'funded'): 0,
#  ('resilience', 'change'): 0.0,
#  ('resilience', 'resiliency'): 0.059854664923740884,
#  ('resilience', 'indicators'): 0,
#  ('resilience', 'buildings'): 0,
#  ('resilience', 'continue'): 0,
#  ('resilience', 'action'): 0,
#  ('adaptive capacity', 'economic'): 0.0,
#  ('adaptive capacity', 'businesses'): 0,
#  ('adaptive capacity', 'residents'): 0,
#  ('adaptive capacity', 'workers'): 0,
#  ('adaptive capacity', 'poverty'): 0,
#  ('adaptive capacity', 'sdgs'): 0,
#  ('adaptive capacity', 'work'): 0,
#  ('adaptive capacity', 'economy'): 0,
#  ('adaptive capacity', 'many'): 0,
#  ('adaptive capacity', 'opportunities'): 0,
#  ('adaptive capacity', 'housing'): 0,
#  ('adaptive capacity', 'affordable'): 0,
#  ('adaptive capacity', 'services'): 0,
#  ('adaptive capacity', 'development'): 0.0,
#  ('adaptive capacity', 'program'): 0,
#  ('adaptive capacity', 'units'): 0,
#  ('adaptive capacity', 'source'): 0,
#  ('adaptive capacity', 'plan'): 0,
#  ('adaptive capacity', 'million'): 0,
#  ('adaptive capacity', 'infrastructure'): 0.0,
#  ('adaptive capacity', 'projects'): 0,
#  ('adaptive capacity', 'bus'): 0,
#  ('adaptive capacity', 'emissions'): 0,
#  ('adaptive capacity', 'capital'): 0,
#  ('adaptive capacity', 'project'): 0,
#  ('adaptive capacity', 'carbon'): 0.0,
#  ('adaptive capacity', 'waste'): 0,
#  ('adaptive capacity', 'delivery'): 0,
#  ('adaptive capacity', 'service'): 0,
#  ('adaptive capacity', 'fair'): 0,
#  ('adaptive capacity', 'strong'): 0,
#  ('adaptive capacity', 'building'): 0.0,
#  ('adaptive capacity', 'healthy'): 0,
#  ('adaptive capacity', 'climate'): 0.02332537582328209,
#  ('adaptive capacity', 'needs'): 0,
#  ('adaptive capacity', 'mental'): 0,
#  ('adaptive capacity', 'equity'): 0,
#  ('adaptive capacity', 'safe'): 0,
#  ('adaptive capacity', 'parks'): 0,
#  ('adaptive capacity', 'social'): 0.0,
#  ('adaptive capacity', 'e'): 0,
#  ('adaptive capacity', 'tag'): 0,
#  ('adaptive capacity', 'media'): 0,
#  ('adaptive capacity', 'early'): 0,
#  ('adaptive capacity', 'free'): 0,
#  ('adaptive capacity', 'diversity'): 0,
#  ('adaptive capacity', 'park'): 0,
#  ('adaptive capacity', 'education'): 0,
#  ('adaptive capacity', 'programs'): 0,
#  ('adaptive capacity', 'every'): 0,
#  ('adaptive capacity', 'training'): 0,
#  ('adaptive capacity', 'library'): 0,
#  ('adaptive capacity', 'computer'): 0,
#  ('adaptive capacity', 'tech'): 0,
#  ('adaptive capacity', 'report'): 0,
#  ('adaptive capacity', 'solar'): 0,
#  ('adaptive capacity', 'global'): 0,
#  ('adaptive capacity', 'government'): 0,
#  ('adaptive capacity', 'electricity'): 0,
#  ('adaptive capacity', 'energy'): 0,
#  ('adaptive capacity', 'mayor'): 0,
#  ('adaptive capacity', 'safety'): 0,
#  ('adaptive capacity', 'streets'): 0,
#  ('adaptive capacity', 'vision'): 0,
#  ('adaptive capacity', 'zero'): 0,
#  ('adaptive capacity', 'pedestrian'): 0,
#  ('adaptive capacity', 'traffic'): 0,
#  ('adaptive capacity', 'lanes'): 0,
#  ('adaptive capacity', 'reduce'): 0,
#  ('adaptive capacity', 'enforcement'): 0,
#  ('adaptive capacity', 'vehicles'): 0,
#  ('adaptive capacity', 'freight'): 0,
#  ('adaptive capacity', 'network'): 0,
#  ('adaptive capacity', 'transit'): 0.0,
#  ('adaptive capacity', 'transportation'): 0.0,
#  ('adaptive capacity', 'deputy'): 0,
#  ('adaptive capacity', 'system'): 0.03855283502525839,
#  ('adaptive capacity', 'funded'): 0,
#  ('adaptive capacity', 'change'): 0.0,
#  ('adaptive capacity', 'resiliency'): 0.0,
#  ('adaptive capacity', 'indicators'): 0,
#  ('adaptive capacity', 'buildings'): 0,
#  ('adaptive capacity', 'continue'): 0,
#  ('adaptive capacity', 'action'): 0,
#  ('vulnerability assessment', 'economic'): 0.0,
#  ('vulnerability assessment', 'businesses'): 0,
#  ('vulnerability assessment', 'residents'): 0,
#  ('vulnerability assessment', 'workers'): 0,
#  ('vulnerability assessment', 'poverty'): 0,
#  ('vulnerability assessment', 'sdgs'): 0,
#  ('vulnerability assessment', 'work'): 0,
#  ('vulnerability assessment', 'economy'): 0,
#  ('vulnerability assessment', 'many'): 0,
#  ('vulnerability assessment', 'opportunities'): 0,
#  ('vulnerability assessment', 'housing'): 0,
#  ('vulnerability assessment', 'affordable'): 0,
#  ('vulnerability assessment', 'services'): 0,
#  ('vulnerability assessment', 'development'): 0.0,
#  ('vulnerability assessment', 'program'): 0,
#  ('vulnerability assessment', 'units'): 0,
#  ('vulnerability assessment', 'source'): 0,
#  ('vulnerability assessment', 'plan'): 0,
#  ('vulnerability assessment', 'million'): 0,
#  ('vulnerability assessment', 'infrastructure'): 0.0,
#  ('vulnerability assessment', 'projects'): 0,
#  ('vulnerability assessment', 'bus'): 0,
#  ('vulnerability assessment', 'emissions'): 0,
#  ('vulnerability assessment', 'capital'): 0,
#  ('vulnerability assessment', 'project'): 0,
#  ('vulnerability assessment', 'carbon'): 0.0,
#  ('vulnerability assessment', 'waste'): 0,
#  ('vulnerability assessment', 'delivery'): 0,
#  ('vulnerability assessment', 'service'): 0,
#  ('vulnerability assessment', 'fair'): 0,
#  ('vulnerability assessment', 'strong'): 0,
#  ('vulnerability assessment', 'building'): 0.0,
#  ('vulnerability assessment', 'healthy'): 0,
#  ('vulnerability assessment', 'climate'): 0.05300290281621264,
#  ('vulnerability assessment', 'needs'): 0,
#  ('vulnerability assessment', 'mental'): 0,
#  ('vulnerability assessment', 'equity'): 0,
#  ('vulnerability assessment', 'safe'): 0,
#  ('vulnerability assessment', 'parks'): 0,
#  ('vulnerability assessment', 'social'): 0.0,
#  ('vulnerability assessment', 'e'): 0,
#  ('vulnerability assessment', 'tag'): 0,
#  ('vulnerability assessment', 'media'): 0,
#  ('vulnerability assessment', 'early'): 0,
#  ('vulnerability assessment', 'free'): 0,
#  ('vulnerability assessment', 'diversity'): 0,
#  ('vulnerability assessment', 'park'): 0,
#  ('vulnerability assessment', 'education'): 0,
#  ('vulnerability assessment', 'programs'): 0,
#  ('vulnerability assessment', 'every'): 0,
#  ('vulnerability assessment', 'training'): 0,
#  ('vulnerability assessment', 'library'): 0,
#  ('vulnerability assessment', 'computer'): 0,
#  ('vulnerability assessment', 'tech'): 0,
#  ('vulnerability assessment', 'report'): 0,
#  ('vulnerability assessment', 'solar'): 0,
#  ('vulnerability assessment', 'global'): 0,
#  ('vulnerability assessment', 'government'): 0,
#  ('vulnerability assessment', 'electricity'): 0,
#  ('vulnerability assessment', 'energy'): 0,
#  ('vulnerability assessment', 'mayor'): 0,
#  ('vulnerability assessment', 'safety'): 0,
#  ('vulnerability assessment', 'streets'): 0,
#  ('vulnerability assessment', 'vision'): 0,
#  ('vulnerability assessment', 'zero'): 0,
#  ('vulnerability assessment', 'pedestrian'): 0,
#  ('vulnerability assessment', 'traffic'): 0,
#  ('vulnerability assessment', 'lanes'): 0,
#  ('vulnerability assessment', 'reduce'): 0,
#  ('vulnerability assessment', 'enforcement'): 0,
#  ('vulnerability assessment', 'vehicles'): 0,
#  ('vulnerability assessment', 'freight'): 0,
#  ('vulnerability assessment', 'network'): 0,
#  ('vulnerability assessment', 'transit'): 0.0,
#  ('vulnerability assessment', 'transportation'): 0.0,
#  ('vulnerability assessment', 'deputy'): 0,
#  ('vulnerability assessment', 'system'): 0.0,
#  ('vulnerability assessment', 'funded'): 0,
#  ('vulnerability assessment', 'change'): 0.0,
#  ('vulnerability assessment', 'resiliency'): 0.0,
#  ('vulnerability assessment', 'indicators'): 0,
#  ('vulnerability assessment', 'buildings'): 0,
#  ('vulnerability assessment', 'continue'): 0,
#  ('vulnerability assessment', 'action'): 0,
#  ('climate proofing', 'economic'): 0.0,
#  ('climate proofing', 'businesses'): 0,
#  ('climate proofing', 'residents'): 0,
#  ('climate proofing', 'workers'): 0,
#  ('climate proofing', 'poverty'): 0,
#  ('climate proofing', 'sdgs'): 0,
#  ('climate proofing', 'work'): 0,
#  ('climate proofing', 'economy'): 0,
#  ('climate proofing', 'many'): 0,
#  ('climate proofing', 'opportunities'): 0,
#  ('climate proofing', 'housing'): 0,
#  ('climate proofing', 'affordable'): 0,
#  ('climate proofing', 'services'): 0,
#  ('climate proofing', 'development'): 0.0,
#  ('climate proofing', 'program'): 0,
#  ('climate proofing', 'units'): 0,
#  ('climate proofing', 'source'): 0,
#  ('climate proofing', 'plan'): 0,
#  ('climate proofing', 'million'): 0,
#  ('climate proofing', 'infrastructure'): 0.061692345398323814,
#  ('climate proofing', 'projects'): 0,
#  ('climate proofing', 'bus'): 0,
#  ('climate proofing', 'emissions'): 0,
#  ('climate proofing', 'capital'): 0,
#  ('climate proofing', 'project'): 0,
#  ('climate proofing', 'carbon'): 0.0,
#  ('climate proofing', 'waste'): 0,
#  ('climate proofing', 'delivery'): 0,
#  ('climate proofing', 'service'): 0,
#  ('climate proofing', 'fair'): 0,
#  ('climate proofing', 'strong'): 0,
#  ('climate proofing', 'building'): 0.0,
#  ('climate proofing', 'healthy'): 0,
#  ('climate proofing', 'climate'): 0.16796396773461245,
#  ('climate proofing', 'needs'): 0,
#  ('climate proofing', 'mental'): 0,
#  ('climate proofing', 'equity'): 0,
#  ('climate proofing', 'safe'): 0,
#  ('climate proofing', 'parks'): 0,
#  ('climate proofing', 'social'): 0.0,
#  ('climate proofing', 'e'): 0,
#  ('climate proofing', 'tag'): 0,
#  ('climate proofing', 'media'): 0,
#  ('climate proofing', 'early'): 0,
#  ('climate proofing', 'free'): 0,
#  ('climate proofing', 'diversity'): 0,
#  ('climate proofing', 'park'): 0,
#  ('climate proofing', 'education'): 0,
#  ('climate proofing', 'programs'): 0,
#  ('climate proofing', 'every'): 0,
#  ('climate proofing', 'training'): 0,
#  ('climate proofing', 'library'): 0,
#  ('climate proofing', 'computer'): 0,
#  ('climate proofing', 'tech'): 0,
#  ('climate proofing', 'report'): 0,
#  ('climate proofing', 'solar'): 0,
#  ('climate proofing', 'global'): 0,
#  ('climate proofing', 'government'): 0,
#  ('climate proofing', 'electricity'): 0,
#  ('climate proofing', 'energy'): 0,
#  ('climate proofing', 'mayor'): 0,
#  ('climate proofing', 'safety'): 0,
#  ('climate proofing', 'streets'): 0,
#  ('climate proofing', 'vision'): 0,
#  ('climate proofing', 'zero'): 0,
#  ('climate proofing', 'pedestrian'): 0,
#  ('climate proofing', 'traffic'): 0,
#  ('climate proofing', 'lanes'): 0,
#  ('climate proofing', 'reduce'): 0,
#  ('climate proofing', 'enforcement'): 0,
#  ('climate proofing', 'vehicles'): 0,
#  ('climate proofing', 'freight'): 0,
#  ('climate proofing', 'network'): 0,
#  ('climate proofing', 'transit'): 0.0,
#  ('climate proofing', 'transportation'): 0.0,
#  ('climate proofing', 'deputy'): 0,
#  ('climate proofing', 'system'): 0.0,
#  ('climate proofing', 'funded'): 0,
#  ('climate proofing', 'change'): 0.061692345398323814,
#  ('climate proofing', 'resiliency'): 0.0,
#  ('climate proofing', 'indicators'): 0,
#  ('climate proofing', 'buildings'): 0,
#  ('climate proofing', 'continue'): 0,
#  ('climate proofing', 'action'): 0,
#  ('ecosystem-based adaptation', 'economic'): 0.0,
#  ('ecosystem-based adaptation', 'businesses'): 0,
#  ('ecosystem-based adaptation', 'residents'): 0,
#  ('ecosystem-based adaptation', 'workers'): 0,
#  ('ecosystem-based adaptation', 'poverty'): 0,
#  ('ecosystem-based adaptation', 'sdgs'): 0,
#  ('ecosystem-based adaptation', 'work'): 0,
#  ('ecosystem-based adaptation', 'economy'): 0,
#  ('ecosystem-based adaptation', 'many'): 0,
#  ('ecosystem-based adaptation', 'opportunities'): 0,
#  ('ecosystem-based adaptation', 'housing'): 0,
#  ('ecosystem-based adaptation', 'affordable'): 0,
#  ('ecosystem-based adaptation', 'services'): 0,
#  ('ecosystem-based adaptation', 'development'): 0.0,
#  ('ecosystem-based adaptation', 'program'): 0,
#  ('ecosystem-based adaptation', 'units'): 0,
#  ('ecosystem-based adaptation', 'source'): 0,
#  ('ecosystem-based adaptation', 'plan'): 0,
#  ('ecosystem-based adaptation', 'million'): 0,
#  ('ecosystem-based adaptation', 'infrastructure'): 0.0,
#  ('ecosystem-based adaptation', 'projects'): 0,
#  ('ecosystem-based adaptation', 'bus'): 0,
#  ('ecosystem-based adaptation', 'emissions'): 0,
#  ('ecosystem-based adaptation', 'capital'): 0,
#  ('ecosystem-based adaptation', 'project'): 0,
#  ('ecosystem-based adaptation', 'carbon'): 0.0,
#  ('ecosystem-based adaptation', 'waste'): 0,
#  ('ecosystem-based adaptation', 'delivery'): 0,
#  ('ecosystem-based adaptation', 'service'): 0,
#  ('ecosystem-based adaptation', 'fair'): 0,
#  ('ecosystem-based adaptation', 'strong'): 0,
#  ('ecosystem-based adaptation', 'building'): 0.0,
#  ('ecosystem-based adaptation', 'healthy'): 0,
#  ('ecosystem-based adaptation', 'climate'): 0.0,
#  ('ecosystem-based adaptation', 'needs'): 0,
#  ('ecosystem-based adaptation', 'mental'): 0,
#  ('ecosystem-based adaptation', 'equity'): 0,
#  ('ecosystem-based adaptation', 'safe'): 0,
#  ('ecosystem-based adaptation', 'parks'): 0,
#  ('ecosystem-based adaptation', 'social'): 0.0,
#  ('ecosystem-based adaptation', 'e'): 0,
#  ('ecosystem-based adaptation', 'tag'): 0,
#  ('ecosystem-based adaptation', 'media'): 0,
#  ('ecosystem-based adaptation', 'early'): 0,
#  ('ecosystem-based adaptation', 'free'): 0,
#  ('ecosystem-based adaptation', 'diversity'): 0,
#  ('ecosystem-based adaptation', 'park'): 0,
#  ('ecosystem-based adaptation', 'education'): 0,
#  ('ecosystem-based adaptation', 'programs'): 0,
#  ('ecosystem-based adaptation', 'every'): 0,
#  ('ecosystem-based adaptation', 'training'): 0,
#  ('ecosystem-based adaptation', 'library'): 0,
#  ('ecosystem-based adaptation', 'computer'): 0,
#  ('ecosystem-based adaptation', 'tech'): 0,
#  ('ecosystem-based adaptation', 'report'): 0,
#  ('ecosystem-based adaptation', 'solar'): 0,
#  ('ecosystem-based adaptation', 'global'): 0,
#  ('ecosystem-based adaptation', 'government'): 0,
#  ('ecosystem-based adaptation', 'electricity'): 0,
#  ('ecosystem-based adaptation', 'energy'): 0,
#  ('ecosystem-based adaptation', 'mayor'): 0,
#  ('ecosystem-based adaptation', 'safety'): 0,
#  ('ecosystem-based adaptation', 'streets'): 0,
#  ('ecosystem-based adaptation', 'vision'): 0,
#  ('ecosystem-based adaptation', 'zero'): 0,
#  ('ecosystem-based adaptation', 'pedestrian'): 0,
#  ('ecosystem-based adaptation', 'traffic'): 0,
#  ('ecosystem-based adaptation', 'lanes'): 0,
#  ('ecosystem-based adaptation', 'reduce'): 0,
#  ('ecosystem-based adaptation', 'enforcement'): 0,
#  ('ecosystem-based adaptation', 'vehicles'): 0,
#  ('ecosystem-based adaptation', 'freight'): 0,
#  ('ecosystem-based adaptation', 'network'): 0,
#  ('ecosystem-based adaptation', 'transit'): 0.0,
#  ('ecosystem-based adaptation', 'transportation'): 0.0,
#  ('ecosystem-based adaptation', 'deputy'): 0,
#  ('ecosystem-based adaptation', 'system'): 0.0,
#  ('ecosystem-based adaptation', 'funded'): 0,
#  ('ecosystem-based adaptation', 'change'): 0.022956897549021745,
#  ('ecosystem-based adaptation', 'resiliency'): 0.0,
#  ('ecosystem-based adaptation', 'indicators'): 0,
#  ('ecosystem-based adaptation', 'buildings'): 0,
#  ('ecosystem-based adaptation', 'continue'): 0,
#  ('ecosystem-based adaptation', 'action'): 0,
#  ('zoning', 'economic'): 0.0,
#  ('zoning', 'businesses'): 0,
#  ('zoning', 'residents'): 0,
#  ('zoning', 'workers'): 0,
#  ('zoning', 'poverty'): 0,
#  ('zoning', 'sdgs'): 0,
#  ('zoning', 'work'): 0,
#  ('zoning', 'economy'): 0,
#  ('zoning', 'many'): 0,
#  ('zoning', 'opportunities'): 0,
#  ('zoning', 'housing'): 0,
#  ('zoning', 'affordable'): 0,
#  ('zoning', 'services'): 0,
#  ('zoning', 'development'): 0.0,
#  ('zoning', 'program'): 0,
#  ('zoning', 'units'): 0,
#  ('zoning', 'source'): 0,
#  ('zoning', 'plan'): 0,
#  ('zoning', 'million'): 0,
#  ('zoning', 'infrastructure'): 0.0,
#  ('zoning', 'projects'): 0,
#  ('zoning', 'bus'): 0,
#  ('zoning', 'emissions'): 0,
#  ('zoning', 'capital'): 0,
#  ('zoning', 'project'): 0,
#  ('zoning', 'carbon'): 0.0,
#  ('zoning', 'waste'): 0,
#  ('zoning', 'delivery'): 0,
#  ('zoning', 'service'): 0,
#  ('zoning', 'fair'): 0,
#  ('zoning', 'strong'): 0,
#  ('zoning', 'building'): 0.0,
#  ('zoning', 'healthy'): 0,
#  ('zoning', 'climate'): 0.0,
#  ('zoning', 'needs'): 0,
#  ('zoning', 'mental'): 0,
#  ('zoning', 'equity'): 0,
#  ('zoning', 'safe'): 0,
#  ('zoning', 'parks'): 0,
#  ('zoning', 'social'): 0.0,
#  ('zoning', 'e'): 0,
#  ('zoning', 'tag'): 0,
#  ('zoning', 'media'): 0,
#  ('zoning', 'early'): 0,
#  ('zoning', 'free'): 0,
#  ('zoning', 'diversity'): 0,
#  ('zoning', 'park'): 0,
#  ('zoning', 'education'): 0,
#  ('zoning', 'programs'): 0,
#  ('zoning', 'every'): 0,
#  ('zoning', 'training'): 0,
#  ('zoning', 'library'): 0,
#  ('zoning', 'computer'): 0,
#  ('zoning', 'tech'): 0,
#  ('zoning', 'report'): 0,
#  ('zoning', 'solar'): 0,
#  ('zoning', 'global'): 0,
#  ('zoning', 'government'): 0,
#  ('zoning', 'electricity'): 0,
#  ('zoning', 'energy'): 0,
#  ('zoning', 'mayor'): 0,
#  ('zoning', 'safety'): 0,
#  ('zoning', 'streets'): 0,
#  ('zoning', 'vision'): 0,
#  ('zoning', 'zero'): 0,
#  ('zoning', 'pedestrian'): 0,
#  ('zoning', 'traffic'): 0,
#  ('zoning', 'lanes'): 0,
#  ('zoning', 'reduce'): 0,
#  ('zoning', 'enforcement'): 0,
#  ('zoning', 'vehicles'): 0,
#  ('zoning', 'freight'): 0,
#  ('zoning', 'network'): 0,
#  ('zoning', 'transit'): 0.0,
#  ('zoning', 'transportation'): 0.0,
#  ('zoning', 'deputy'): 0,
#  ('zoning', 'system'): 0.0,
#  ('zoning', 'funded'): 0,
#  ('zoning', 'change'): 0.0,
#  ('zoning', 'resiliency'): 0.0,
#  ('zoning', 'indicators'): 0,
#  ('zoning', 'buildings'): 0,
#  ('zoning', 'continue'): 0,
#  ('zoning', 'action'): 0,
#  ('land use planning', 'economic'): 0.0,
#  ('land use planning', 'businesses'): 0,
#  ('land use planning', 'residents'): 0,
#  ('land use planning', 'workers'): 0,
#  ('land use planning', 'poverty'): 0,
#  ('land use planning', 'sdgs'): 0,
#  ('land use planning', 'work'): 0,
#  ('land use planning', 'economy'): 0,
#  ('land use planning', 'many'): 0,
#  ('land use planning', 'opportunities'): 0,
#  ('land use planning', 'housing'): 0,
#  ('land use planning', 'affordable'): 0,
#  ('land use planning', 'services'): 0,
#  ('land use planning', 'development'): 0.01293824537904227,
#  ('land use planning', 'program'): 0,
#  ('land use planning', 'units'): 0,
#  ('land use planning', 'source'): 0,
#  ('land use planning', 'plan'): 0,
#  ('land use planning', 'million'): 0,
#  ('land use planning', 'infrastructure'): 0.0,
#  ('land use planning', 'projects'): 0,
#  ('land use planning', 'bus'): 0,
#  ('land use planning', 'emissions'): 0,
#  ('land use planning', 'capital'): 0,
#  ('land use planning', 'project'): 0,
#  ('land use planning', 'carbon'): 0.0,
#  ('land use planning', 'waste'): 0,
#  ('land use planning', 'delivery'): 0,
#  ('land use planning', 'service'): 0,
#  ('land use planning', 'fair'): 0,
#  ('land use planning', 'strong'): 0,
#  ('land use planning', 'building'): 0.0,
#  ('land use planning', 'healthy'): 0,
#  ('land use planning', 'climate'): 0.0,
#  ('land use planning', 'needs'): 0,
#  ('land use planning', 'mental'): 0,
#  ('land use planning', 'equity'): 0,
#  ('land use planning', 'safe'): 0,
#  ('land use planning', 'parks'): 0,
#  ('land use planning', 'social'): 0.0,
#  ('land use planning', 'e'): 0,
#  ('land use planning', 'tag'): 0,
#  ('land use planning', 'media'): 0,
#  ('land use planning', 'early'): 0,
#  ('land use planning', 'free'): 0,
#  ('land use planning', 'diversity'): 0,
#  ('land use planning', 'park'): 0,
#  ('land use planning', 'education'): 0,
#  ('land use planning', 'programs'): 0,
#  ('land use planning', 'every'): 0,
#  ('land use planning', 'training'): 0,
#  ('land use planning', 'library'): 0,
#  ('land use planning', 'computer'): 0,
#  ('land use planning', 'tech'): 0,
#  ('land use planning', 'report'): 0,
#  ('land use planning', 'solar'): 0,
#  ('land use planning', 'global'): 0,
#  ('land use planning', 'government'): 0,
#  ('land use planning', 'electricity'): 0,
#  ('land use planning', 'energy'): 0,
#  ('land use planning', 'mayor'): 0,
#  ('land use planning', 'safety'): 0,
#  ('land use planning', 'streets'): 0,
#  ('land use planning', 'vision'): 0,
#  ('land use planning', 'zero'): 0,
#  ('land use planning', 'pedestrian'): 0,
#  ('land use planning', 'traffic'): 0,
#  ('land use planning', 'lanes'): 0,
#  ('land use planning', 'reduce'): 0,
#  ('land use planning', 'enforcement'): 0,
#  ('land use planning', 'vehicles'): 0,
#  ('land use planning', 'freight'): 0,
#  ('land use planning', 'network'): 0,
#  ('land use planning', 'transit'): 0.0,
#  ('land use planning', 'transportation'): 0.0,
#  ('land use planning', 'deputy'): 0,
#  ('land use planning', 'system'): 0.0,
#  ('land use planning', 'funded'): 0,
#  ('land use planning', 'change'): 0.0,
#  ('land use planning', 'resiliency'): 0.0,
#  ('land use planning', 'indicators'): 0,
#  ('land use planning', 'buildings'): 0,
#  ('land use planning', 'continue'): 0,
#  ('land use planning', 'action'): 0,
#  ('urban design', 'economic'): 0.0,
#  ('urban design', 'businesses'): 0,
#  ('urban design', 'residents'): 0,
#  ('urban design', 'workers'): 0,
#  ('urban design', 'poverty'): 0,
#  ('urban design', 'sdgs'): 0,
#  ('urban design', 'work'): 0,
#  ('urban design', 'economy'): 0,
#  ('urban design', 'many'): 0,
#  ('urban design', 'opportunities'): 0,
#  ('urban design', 'housing'): 0,
#  ('urban design', 'affordable'): 0,
#  ('urban design', 'services'): 0,
#  ('urban design', 'development'): 0.025653311442270597,
#  ('urban design', 'program'): 0,
#  ('urban design', 'units'): 0,
#  ('urban design', 'source'): 0,
#  ('urban design', 'plan'): 0,
#  ('urban design', 'million'): 0,
#  ('urban design', 'infrastructure'): 0.0,
#  ('urban design', 'projects'): 0,
#  ('urban design', 'bus'): 0,
#  ('urban design', 'emissions'): 0,
#  ('urban design', 'capital'): 0,
#  ('urban design', 'project'): 0,
#  ('urban design', 'carbon'): 0.0,
#  ('urban design', 'waste'): 0,
#  ('urban design', 'delivery'): 0,
#  ('urban design', 'service'): 0,
#  ('urban design', 'fair'): 0,
#  ('urban design', 'strong'): 0,
#  ('urban design', 'building'): 0.0,
#  ('urban design', 'healthy'): 0,
#  ('urban design', 'climate'): 0.0,
#  ('urban design', 'needs'): 0,
#  ('urban design', 'mental'): 0,
#  ('urban design', 'equity'): 0,
#  ('urban design', 'safe'): 0,
#  ('urban design', 'parks'): 0,
#  ('urban design', 'social'): 0.0,
#  ('urban design', 'e'): 0,
#  ('urban design', 'tag'): 0,
#  ('urban design', 'media'): 0,
#  ('urban design', 'early'): 0,
#  ('urban design', 'free'): 0,
#  ('urban design', 'diversity'): 0,
#  ('urban design', 'park'): 0,
#  ('urban design', 'education'): 0,
#  ('urban design', 'programs'): 0,
#  ('urban design', 'every'): 0,
#  ('urban design', 'training'): 0,
#  ('urban design', 'library'): 0,
#  ('urban design', 'computer'): 0,
#  ('urban design', 'tech'): 0,
#  ('urban design', 'report'): 0,
#  ('urban design', 'solar'): 0,
#  ('urban design', 'global'): 0,
#  ('urban design', 'government'): 0,
#  ('urban design', 'electricity'): 0,
#  ('urban design', 'energy'): 0,
#  ('urban design', 'mayor'): 0,
#  ('urban design', 'safety'): 0,
#  ('urban design', 'streets'): 0,
#  ('urban design', 'vision'): 0,
#  ('urban design', 'zero'): 0,
#  ('urban design', 'pedestrian'): 0,
#  ('urban design', 'traffic'): 0,
#  ('urban design', 'lanes'): 0,
#  ('urban design', 'reduce'): 0,
#  ('urban design', 'enforcement'): 0,
#  ('urban design', 'vehicles'): 0,
#  ('urban design', 'freight'): 0,
#  ('urban design', 'network'): 0,
#  ('urban design', 'transit'): 0.0,
#  ('urban design', 'transportation'): 0.0,
#  ('urban design', 'deputy'): 0,
#  ('urban design', 'system'): 0.0,
#  ('urban design', 'funded'): 0,
#  ('urban design', 'change'): 0.0,
#  ('urban design', 'resiliency'): 0.0,
#  ('urban design', 'indicators'): 0,
#  ('urban design', 'buildings'): 0,
#  ('urban design', 'continue'): 0,
#  ('urban design', 'action'): 0,
#  ('transportation planning', 'economic'): 0.0,
#  ('transportation planning', 'businesses'): 0,
#  ('transportation planning', 'residents'): 0,
#  ('transportation planning', 'workers'): 0,
#  ('transportation planning', 'poverty'): 0,
#  ('transportation planning', 'sdgs'): 0,
#  ('transportation planning', 'work'): 0,
#  ('transportation planning', 'economy'): 0,
#  ('transportation planning', 'many'): 0,
#  ('transportation planning', 'opportunities'): 0,
#  ('transportation planning', 'housing'): 0,
#  ('transportation planning', 'affordable'): 0,
#  ('transportation planning', 'services'): 0,
#  ('transportation planning', 'development'): 0.0,
#  ('transportation planning', 'program'): 0,
#  ('transportation planning', 'units'): 0,
#  ('transportation planning', 'source'): 0,
#  ('transportation planning', 'plan'): 0,
#  ('transportation planning', 'million'): 0,
#  ('transportation planning', 'infrastructure'): 0.03986354225358604,
#  ('transportation planning', 'projects'): 0,
#  ('transportation planning', 'bus'): 0,
#  ('transportation planning', 'emissions'): 0,
#  ('transportation planning', 'capital'): 0,
#  ('transportation planning', 'project'): 0,
#  ('transportation planning', 'carbon'): 0.0,
#  ('transportation planning', 'waste'): 0,
#  ('transportation planning', 'delivery'): 0,
#  ('transportation planning', 'service'): 0,
#  ('transportation planning', 'fair'): 0,
#  ('transportation planning', 'strong'): 0,
#  ('transportation planning', 'building'): 0.0,
#  ('transportation planning', 'healthy'): 0,
#  ('transportation planning', 'climate'): 0.0,
#  ('transportation planning', 'needs'): 0,
#  ('transportation planning', 'mental'): 0,
#  ('transportation planning', 'equity'): 0,
#  ('transportation planning', 'safe'): 0,
#  ('transportation planning', 'parks'): 0,
#  ('transportation planning', 'social'): 0.0,
#  ('transportation planning', 'e'): 0,
#  ('transportation planning', 'tag'): 0,
#  ('transportation planning', 'media'): 0,
#  ('transportation planning', 'early'): 0,
#  ('transportation planning', 'free'): 0,
#  ('transportation planning', 'diversity'): 0,
#  ('transportation planning', 'park'): 0,
#  ('transportation planning', 'education'): 0,
#  ('transportation planning', 'programs'): 0,
#  ('transportation planning', 'every'): 0,
#  ('transportation planning', 'training'): 0,
#  ('transportation planning', 'library'): 0,
#  ('transportation planning', 'computer'): 0,
#  ('transportation planning', 'tech'): 0,
#  ('transportation planning', 'report'): 0,
#  ('transportation planning', 'solar'): 0,
#  ('transportation planning', 'global'): 0,
#  ('transportation planning', 'government'): 0,
#  ('transportation planning', 'electricity'): 0,
#  ('transportation planning', 'energy'): 0,
#  ('transportation planning', 'mayor'): 0,
#  ('transportation planning', 'safety'): 0,
#  ('transportation planning', 'streets'): 0,
#  ('transportation planning', 'vision'): 0,
#  ('transportation planning', 'zero'): 0,
#  ('transportation planning', 'pedestrian'): 0,
#  ('transportation planning', 'traffic'): 0,
#  ('transportation planning', 'lanes'): 0,
#  ('transportation planning', 'reduce'): 0,
#  ('transportation planning', 'enforcement'): 0,
#  ('transportation planning', 'vehicles'): 0,
#  ('transportation planning', 'freight'): 0,
#  ('transportation planning', 'network'): 0,
#  ('transportation planning', 'transit'): 0.05516259430080556,
#  ('transportation planning', 'transportation'): 0.1654877829024167,
#  ('transportation planning', 'deputy'): 0,
#  ('transportation planning', 'system'): 0.0,
#  ('transportation planning', 'funded'): 0,
#  ('transportation planning', 'change'): 0.0,
#  ('transportation planning', 'resiliency'): 0.0,
#  ('transportation planning', 'indicators'): 0,
#  ('transportation planning', 'buildings'): 0,
#  ('transportation planning', 'continue'): 0,
#  ('transportation planning', 'action'): 0,
#  ('sustainable development', 'economic'): 0.03683082836407575,
#  ('sustainable development', 'businesses'): 0,
#  ('sustainable development', 'residents'): 0,
#  ('sustainable development', 'workers'): 0,
#  ('sustainable development', 'poverty'): 0,
#  ('sustainable development', 'sdgs'): 0,
#  ('sustainable development', 'work'): 0,
#  ('sustainable development', 'economy'): 0,
#  ('sustainable development', 'many'): 0,
#  ('sustainable development', 'opportunities'): 0,
#  ('sustainable development', 'housing'): 0,
#  ('sustainable development', 'affordable'): 0,
#  ('sustainable development', 'services'): 0,
#  ('sustainable development', 'development'): 0.14260656793560222,
#  ('sustainable development', 'program'): 0,
#  ('sustainable development', 'units'): 0,
#  ('sustainable development', 'source'): 0,
#  ('sustainable development', 'plan'): 0,
#  ('sustainable development', 'million'): 0,
#  ('sustainable development', 'infrastructure'): 0.0,
#  ('sustainable development', 'projects'): 0,
#  ('sustainable development', 'bus'): 0,
#  ('sustainable development', 'emissions'): 0,
#  ('sustainable development', 'capital'): 0,
#  ('sustainable development', 'project'): 0,
#  ('sustainable development', 'carbon'): 0.03683082836407575,
#  ('sustainable development', 'waste'): 0,
#  ('sustainable development', 'delivery'): 0,
#  ('sustainable development', 'service'): 0,
#  ('sustainable development', 'fair'): 0,
#  ('sustainable development', 'strong'): 0,
#  ('sustainable development', 'building'): 0.0,
#  ('sustainable development', 'healthy'): 0,
#  ('sustainable development', 'climate'): 0.0,
#  ('sustainable development', 'needs'): 0,
#  ('sustainable development', 'mental'): 0,
#  ('sustainable development', 'equity'): 0,
#  ('sustainable development', 'safe'): 0,
#  ('sustainable development', 'parks'): 0,
#  ('sustainable development', 'social'): 0.03683082836407575,
#  ('sustainable development', 'e'): 0,
#  ('sustainable development', 'tag'): 0,
#  ('sustainable development', 'media'): 0,
#  ('sustainable development', 'early'): 0,
#  ('sustainable development', 'free'): 0,
#  ('sustainable development', 'diversity'): 0,
#  ('sustainable development', 'park'): 0,
#  ('sustainable development', 'education'): 0,
#  ('sustainable development', 'programs'): 0,
#  ('sustainable development', 'every'): 0,
#  ('sustainable development', 'training'): 0,
#  ('sustainable development', 'library'): 0,
#  ('sustainable development', 'computer'): 0,
#  ('sustainable development', 'tech'): 0,
#  ('sustainable development', 'report'): 0,
#  ('sustainable development', 'solar'): 0,
#  ('sustainable development', 'global'): 0,
#  ('sustainable development', 'government'): 0,
#  ('sustainable development', 'electricity'): 0,
#  ('sustainable development', 'energy'): 0,
#  ('sustainable development', 'mayor'): 0,
#  ('sustainable development', 'safety'): 0,
#  ('sustainable development', 'streets'): 0,
#  ('sustainable development', 'vision'): 0,
#  ('sustainable development', 'zero'): 0,
#  ('sustainable development', 'pedestrian'): 0,
#  ('sustainable development', 'traffic'): 0,
#  ('sustainable development', 'lanes'): 0,
#  ('sustainable development', 'reduce'): 0,
#  ('sustainable development', 'enforcement'): 0,
#  ('sustainable development', 'vehicles'): 0,
#  ('sustainable development', 'freight'): 0,
#  ('sustainable development', 'network'): 0,
#  ('sustainable development', 'transit'): 0.0,
#  ('sustainable development', 'transportation'): 0.0,
#  ('sustainable development', 'deputy'): 0,
#  ('sustainable development', 'system'): 0.0,
#  ('sustainable development', 'funded'): 0,
#  ('sustainable development', 'change'): 0.0,
#  ('sustainable development', 'resiliency'): 0.0,
#  ('sustainable development', 'indicators'): 0,
#  ('sustainable development', 'buildings'): 0,
#  ('sustainable development', 'continue'): 0,
#  ('sustainable development', 'action'): 0}

# %%
node_total_scores
# Out:
# {'resilience': 0.18913349027502765,
#  'adaptive capacity': 0.061878210848540484,
#  'vulnerability assessment': 0.05300290281621264,
#  'climate proofing': 0.2913486585312601,
#  'ecosystem-based adaptation': 0.022956897549021745,
#  'zoning': 0.0,
#  'land use planning': 0.01293824537904227,
#  'urban design': 0.025653311442270597,
#  'transportation planning': 0.2605139194568083,
#  'sustainable development': 0.2530990530278295}

# %%
custom_order
# Out:
# ['resilience',
#  'adaptive capacity',
#  'vulnerability assessment',
#  'climate proofing',
#  'ecosystem-based adaptation',
#  'zoning',
#  'land use planning',
#  'urban design',
#  'transportation planning',
#  'sustainable development']

# %%
# 1. 初始化 topic_word_weights 字典
topic_word_weights = {topic: {} for topic in custom_order}

# 2. 填充 topic_word_weights 字典
for (topic, word), weight in correlation_scores.items():
    if topic in topic_word_weights:
        topic_word_weights[topic][word] = weight

# 打印结果
print(topic_word_weights)
# Out:
# {'resilience': {'economic': 0.0, 'businesses': 0, 'residents': 0, 'workers': 0, 'poverty': 0, 'sdgs': 0, 'work': 0, 'economy': 0, 'many': 0, 'opportunities': 0, 'housing': 0, 'affordable': 0, 'services': 0, 'development': 0.0, 'program': 0, 'units': 0, 'source': 0, 'plan': 0, 'million': 0, 'infrastructure': 0.0, 'projects': 0, 'bus': 0, 'emissions': 0, 'capital': 0, 'project': 0, 'carbon': 0.0, 'waste': 0, 'delivery': 0, 'service': 0, 'fair': 0, 'strong': 0, 'building': 0.059854664923740884, 'healthy': 0, 'climate': 0.0261698683750248, 'needs': 0, 'mental': 0, 'equity': 0, 'safe': 0, 'parks': 0, 'social': 0.0, 'e': 0, 'tag': 0, 'media': 0, 'early': 0, 'free': 0, 'diversity': 0, 'park': 0, 'education': 0, 'programs': 0, 'every': 0, 'training': 0, 'library': 0, 'computer': 0, 'tech': 0, 'report': 0, 'solar': 0, 'global': 0, 'government': 0, 'electricity': 0, 'energy': 0, 'mayor': 0, 'safety': 0, 'streets': 0, 'vision': 0, 'zero': 0, 'pedestrian': 0, 'traffic': 0, 'lanes': 0, 'reduce': 0, 'enforcement': 0, 'vehicles': 0, 'freight': 0, 'network': 0, 'transit': 0.0, 'transportation': 0.0, 'deputy': 0, 'system': 0.043254292052521084, 'funded': 0, 'change': 0.0, 'resiliency': 0.059854664923740884, 'indicators': 0, 'buildings': 0, 'continue': 0, 'action': 0}, 'adaptive capacity': {'economic': 0.0, 'businesses': 0, 'residents': 0, 'workers': 0, 'poverty': 0, 'sdgs': 0, 'work': 0, 'economy': 0, 'many': 0, 'opportunities': 0, 'housing': 0, 'affordable': 0, 'services': 0, 'development': 0.0, 'program': 0, 'units': 0, 'source': 0, 'plan': 0, 'million': 0, 'infrastructure': 0.0, 'projects': 0, 'bus': 0, 'emissions': 0, 'capital': 0, 'project': 0, 'carbon': 0.0, 'waste': 0, 'delivery': 0, 'service': 0, 'fair': 0, 'strong': 0, 'building': 0.0, 'healthy': 0, 'climate': 0.02332537582328209, 'needs': 0, 'mental': 0, 'equity': 0, 'safe': 0, 'parks': 0, 'social': 0.0, 'e': 0, 'tag': 0, 'media': 0, 'early': 0, 'free': 0, 'diversity': 0, 'park': 0, 'education': 0, 'programs': 0, 'every': 0, 'training': 0, 'library': 0, 'computer': 0, 'tech': 0, 'report': 0, 'solar': 0, 'global': 0, 'government': 0, 'electricity': 0, 'energy': 0, 'mayor': 0, 'safety': 0, 'streets': 0, 'vision': 0, 'zero': 0, 'pedestrian': 0, 'traffic': 0, 'lanes': 0, 'reduce': 0, 'enforcement': 0, 'vehicles': 0, 'freight': 0, 'network': 0, 'transit': 0.0, 'transportation': 0.0, 'deputy': 0, 'system': 0.03855283502525839, 'funded': 0, 'change': 0.0, 'resiliency': 0.0, 'indicators': 0, 'buildings': 0, 'continue': 0, 'action': 0}, 'vulnerability assessment': {'economic': 0.0, 'businesses': 0, 'residents': 0, 'workers': 0, 'poverty': 0, 'sdgs': 0, 'work': 0, 'economy': 0, 'many': 0, 'opportunities': 0, 'housing': 0, 'affordable': 0, 'services': 0, 'development': 0.0, 'program': 0, 'units': 0, 'source': 0, 'plan': 0, 'million': 0, 'infrastructure': 0.0, 'projects': 0, 'bus': 0, 'emissions': 0, 'capital': 0, 'project': 0, 'carbon': 0.0, 'waste': 0, 'delivery': 0, 'service': 0, 'fair': 0, 'strong': 0, 'building': 0.0, 'healthy': 0, 'climate': 0.05300290281621264, 'needs': 0, 'mental': 0, 'equity': 0, 'safe': 0, 'parks': 0, 'social': 0.0, 'e': 0, 'tag': 0, 'media': 0, 'early': 0, 'free': 0, 'diversity': 0, 'park': 0, 'education': 0, 'programs': 0, 'every': 0, 'training': 0, 'library': 0, 'computer': 0, 'tech': 0, 'report': 0, 'solar': 0, 'global': 0, 'government': 0, 'electricity': 0, 'energy': 0, 'mayor': 0, 'safety': 0, 'streets': 0, 'vision': 0, 'zero': 0, 'pedestrian': 0, 'traffic': 0, 'lanes': 0, 'reduce': 0, 'enforcement': 0, 'vehicles': 0, 'freight': 0, 'network': 0, 'transit': 0.0, 'transportation': 0.0, 'deputy': 0, 'system': 0.0, 'funded': 0, 'change': 0.0, 'resiliency': 0.0, 'indicators': 0, 'buildings': 0, 'continue': 0, 'action': 0}, 'climate proofing': {'economic': 0.0, 'businesses': 0, 'residents': 0, 'workers': 0, 'poverty': 0, 'sdgs': 0, 'work': 0, 'economy': 0, 'many': 0, 'opportunities': 0, 'housing': 0, 'affordable': 0, 'services': 0, 'development': 0.0, 'program': 0, 'un ...

# %% [markdown]
# Weighted Topic Co-occurrence via Shared Word Nodes

# %%
# 初始化主题节点之间的间接共现频率字典
topic_cooccurrence = {topic1: {topic2: 0 for topic2 in topic_word_weights.keys()}
                      for topic1 in topic_word_weights.keys()}

# 遍历所有主题对
for topic1 in topic_word_weights.keys():
    for topic2 in topic_word_weights.keys():
        if topic1 == topic2:
            continue  # 跳过自己与自己的共现

        # 遍历 topic1 和 topic2 关联的词节点
        for word1, weight1 in topic_word_weights[topic1].items():
            for word2, weight2 in topic_word_weights[topic2].items():
                # 获取词节点间的共现权重
                if word1 in word_nodes and word2 in word_nodes:
                    idx1 = word_nodes.index(word1)
                    idx2 = word_nodes.index(word2)
                    word_cooccurrence_weight = word_cooccurrence_matrix[idx1, idx2]

                    # 累加到主题之间的共现权重
                    topic_cooccurrence[topic1][topic2] += weight1 * weight2 * word_cooccurrence_weight

# 输出结果
print("Topic Co-occurrence Weights:")
for topic1, connections in topic_cooccurrence.items():
    for topic2, weight in connections.items():
        if weight > 0:
            print(f"{topic1} <-> {topic2}: {weight:.4f}")
# Out:
# Topic Co-occurrence Weights:
# resilience <-> adaptive capacity: 0.0052
# resilience <-> vulnerability assessment: 0.0043
# resilience <-> climate proofing: 0.0246
# resilience <-> ecosystem-based adaptation: 0.0022
# resilience <-> land use planning: 0.0012
# resilience <-> urban design: 0.0023
# resilience <-> transportation planning: 0.0194
# resilience <-> sustainable development: 0.0229
# adaptive capacity <-> resilience: 0.0052
# adaptive capacity <-> vulnerability assessment: 0.0009
# adaptive capacity <-> climate proofing: 0.0060
# adaptive capacity <-> ecosystem-based adaptation: 0.0005
# adaptive capacity <-> land use planning: 0.0004
# adaptive capacity <-> urban design: 0.0007
# adaptive capacity <-> transportation planning: 0.0075
# adaptive capacity <-> sustainable development: 0.0073
# vulnerability assessment <-> resilience: 0.0043
# vulnerability assessment <-> adaptive capacity: 0.0009
# vulnerability assessment <-> climate proofing: 0.0072
# vulnerability assessment <-> ecosystem-based adaptation: 0.0005
# vulnerability assessment <-> land use planning: 0.0004
# vulnerability assessment <-> urban design: 0.0008
# vulnerability assessment <-> transportation planning: 0.0107
# vulnerability assessment <-> sustainable development: 0.0072
# climate proofing <-> resilience: 0.0246
# climate proofing <-> adaptive capacity: 0.0060
# climate proofing <-> vulnerability assessment: 0.0072
# climate proofing <-> ecosystem-based adaptation: 0.0030
# climate proofing <-> land use planning: 0.0019
# climate proofing <-> urban design: 0.0037
# climate proofing <-> transportation planning: 0.0490
# climate proofing <-> sustainable development: 0.0362
# ecosystem-based adaptation <-> resilience: 0.0022
# ecosystem-based adaptation <-> adaptive capacity: 0.0005
# ecosystem-based adaptation <-> vulnerability assessment: 0.0005
# ecosystem-based adaptation <-> climate proofing: 0.0030
# ecosystem-based adaptation <-> land use planning: 0.0001
# ecosystem-based adaptation <-> urban design: 0.0003
# ecosystem-based adaptation <-> transportation planning: 0.0024
# ecosystem-based adaptation <-> sustainable development: 0.0031
# land use planning <-> resilience: 0.0012
# land use planning <-> adaptive capacity: 0.0004
# land use planning <-> vulnerability assessment: 0.0004
# land use planning <-> climate proofing: 0.0019
# land use planning <-> ecosystem-based adaptation: 0.0001
# land use planning <-> urban design: 0.0002
# land use planning <-> transportation planning: 0.0021
# land use planning <-> sustainable development: 0.0024
# urban design <-> resilience: 0.0023
# urban design <-> adaptive capacity: 0.0007
# urban design <-> vulnerability assessment: 0.0008
# urban design <-> climate proofing: 0.0037
# urban design <-> ecosystem-based adaptation: 0.0003
# urban design <-> land use planning: 0.0002
# urban design <-> transportation planning: 0.0043
# urban design <-> sustainable development: 0.0047
# transportation planning <-> resilience: 0.0194
# transportation planning <-> adaptive capacity: 0.0075
# transportation planning <-> vulnerability assessment: 0.0107
# transportation planning <-> climate proofing: 0.0490
# transportation planning <-> ecosystem-based adaptation: 0.0024
# transportation planning <-> land use planning: 0.0021
# transportation planning <-> urban design: 0.0043
# transportation planning <-> sustainable development: 0.0371
# sustainable development <-> resilience: 0.0229
# sustainable development <-> adaptive capacity: 0.0073
# sustainable development <-> vulnerability assessment: 0.0072
# sustainable development <-> climate proofing: 0.0362
# sustainable development <-> ecosystem-based adaptation: 0.0031
# sustainable development <-> land use planning: 0.0024
# sustainable development <-> urban design: 0.0047
# sustainable development <-> transportation planning: 0.0371

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Patch
from matplotlib.lines import Line2D

# 构建图
G = nx.Graph()  # 如果需要有向图，改为 nx.DiGraph()

# 添加节点
for topic in topic_cooccurrence.keys():
    G.add_node(topic)

# 添加边及权重
for topic1, connections in topic_cooccurrence.items():
    for topic2, weight in connections.items():
        if weight > 0:  # 只添加有权重的边
            G.add_edge(topic1, topic2, weight=weight)

# 使用圆形布局并添加扰动
pos = nx.circular_layout(G)
np.random.seed(42)  # 固定随机种子以复现

# 提取边的权重
edges = G.edges(data=True)
weights = [data['weight'] for _, _, data in edges]

# 归一化权重到 1 到 10
min_weight, max_weight = min(weights), max(weights)
normalized_weights = [
    0 + (weight - min_weight) / (max_weight - min_weight) * 10 for weight in weights
]

# 生成用于图例的示例边权重
example_weights = np.linspace(min_weight, max_weight, 6)  # 生成五个等间隔的权重
example_widths = [
    0 + (w - min_weight) / (max_weight - min_weight) * 10 for w in example_weights
]
# 移除第一个权重和对应的宽度
example_weights = example_weights[1:]
example_widths = example_widths[1:]


# 绘制图
plt.figure(figsize=(12, 12))
nx.draw_networkx_nodes(
    G, pos, node_size=sizes, node_color='skyblue', edgecolors='black'
)
nx.draw_networkx_edges(G, pos, width=normalized_weights, alpha=0.7)
nx.draw_networkx_labels(G, pos, font_size=10, font_color='black')


# 添加图例
legend_elements = [
    Patch(facecolor='skyblue', edgecolor='black', label='Topic Node')
]

# 添加边权重示例
for w, width in zip(example_weights, example_widths):
    legend_elements.append(
        Line2D(
            [0], [0],
            color='gray',
            lw=width,
            label=f"Weight: {w:.2f}"
        )
    )

plt.legend(
    handles=legend_elements,
    loc="upper right",
    fontsize=10,
    title="Legend",
    title_fontsize=12,
    frameon=True,
)

# 显示图
plt.title("Topic Node-Edge Graph\nNode:(LDA+TF-IDF),Edge:indirect Co-occurance")
plt.axis('off')
plt.show()
